# %%
import gc
import operator 
import re
import keras
import pandas as pd
import numpy as np
import seaborn as snss
import matplotlib.pyplot as plt
sns.set_style('whitegrid')
from tqdm import tqdm
tqdm.pandas()

# %% [markdown]
# ## Loading data

# %%
train = pd.read_csv("../input/train.csv")
test = pd.read_csv("../input/test.csv")
df = pd.concat([train ,test], sort=False)
print("Number of texts: ", df.shape[0])
# Out:
# Number of texts:  1362492

# %% [markdown]
# ## Loading embeddings

# %%
def load_emb(filename):
    def get_coefs(word, *arr): 
        return word, np.asarray(arr, dtype='float32')
    if "wiki-news-300d-1M.vec" in filename:
        embeddings_index = dict(get_coefs(*o.split(" ")) for o in open(filename) if len(o)>100)
    else:
        embeddings_index = dict(get_coefs(*o.split(" ")) for o in open(filename, encoding='latin'))
    return embeddings_index

glove = '../input/embeddings/glove.840B.300d/glove.840B.300d.txt'
print("Extracting GloVe embedding")
emb_glove = load_emb(glove)
# Out:
# Extracting GloVe embedding

# %% [markdown]
# ## Vocabulary and Coverage functions

# %%
def build_vocab(texts):
    sentences = texts.apply(lambda x: x.split()).values
    vocab = {}
    for sentence in sentences:
        for word in sentence:
            try:
                vocab[word] += 1
            except KeyError:
                vocab[word] = 1
    return vocab

def check_coverage(vocab, embeddings_index):
    known_words = {}
    unknown_words = {}
    nb_known_words = 0
    nb_unknown_words = 0
    for word in vocab.keys():
        try:
            known_words[word] = embeddings_index[word]
            nb_known_words += vocab[word]
        except:
            unknown_words[word] = vocab[word]
            nb_unknown_words += vocab[word]
    print('Found embeddings for {:.3%} of vocab'.format(len(known_words) / len(vocab)))
    print('Found embeddings for  {:.3%} of all text'.format(nb_known_words / (nb_known_words + nb_unknown_words)))
    unknown_words = sorted(unknown_words.items(), key=operator.itemgetter(1))[::-1]
    return unknown_words

# %% [markdown]
# ## Starting point

# %%
vocab = build_vocab(df['question_text'])
print("Glove : ")
oov_glove = check_coverage(vocab, emb_glove)
# Out:
# Glove :
# Found embeddings for 32.773% of vocab
# Found embeddings for  88.149% of all text

# %% [markdown]
# Apply lowerization (necessary if using paragram)
# > Fasttext and GloVe understand capitalization, but you still win a bit.

# %%
df['lowered_question'] = df['question_text'].apply(lambda x: x.lower())

# %% [markdown]
# If you apply lowerization, you lost a bit of informations on other embeddings:
# > Therer are words known that are known with upper letters and unknown without. Let us fix that:
# * word.lower() takes the embedding of word if word.lower() doesn't have an embedding

# %%
def add_lower(embedding, vocab):
    count = 0
    for word in vocab:
        if word in embedding and word.lower() not in embedding:  
            embedding[word.lower()] = embedding[word]
            count += 1
    print(f"Added {count} words to embedding")

# %%
print("Glove: ")
oov_glove = check_coverage(vocab, emb_glove)
add_lower(emb_glove, vocab)
oov_glove = check_coverage(vocab, emb_glove)
# Out:
# Glove:
# Found embeddings for 32.773% of vocab
# Found embeddings for  88.149% of all text
# Added 15199 words to embedding
# Found embeddings for 33.029% of vocab
# Found embeddings for  88.164% of all text

# %% [markdown]
# ## What's wrong?

# %%
oov_glove[:10]
# Out:
# [('India?', 17082),
#  ('it?', 13436),
#  ("What's", 12985),
#  ('do?', 9112),
#  ('life?', 8074),
#  ('you?', 6553),
#  ('me?', 6485),
#  ('them?', 6421),
#  ('time?', 5994),
#  ('world?', 5632)]

# %% [markdown]
# First faults appearing are:
#
# * Contractions
# * Words with punctuation in them
#
# > Let us correct that.

# %% [markdown]
# ## Contractions

# %%
contractions = {"ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because",
                "could've": "could have", "couldn't": "could not", "didn't": "did not",
                "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not",
                "haven't": "have not", "he'd": "he would","he'll": "he will", "he's": "he is",
                "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is",
                "i'd": "i would", "i'd've": "i would have", "i'll": "i will", "i'll've": "i will have",
                "i'm": "i am", "i've": "i have", "i'd": "i would", "i'd've": "i would have",
                "i'll": "i will",  "i'll've": "i will have","i'm": "i am", "i've": "i have",
                "isn't": "is not", "it'd": "it would", "it'd've": "it would have", "it'll": "it will",
                "it'll've": "it will have","it's": "it is", "let's": "let us", "ma'am": "madam",
                "mayn't": "may not", "might've": "might have","mightn't": "might not","mightn't've": "might not have",
                "must've": "must have", "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not",
                "needn't've": "need not have","o'clock": "of the clock", "oughtn't": "ought not",
                "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not",
                "shan't've": "shall not have", "she'd": "she would", "she'd've": "she would have",
                "she'll": "she will", "she'll've": "she will have", "she's": "she is", "should've": "should have",
                "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have","so's": "so as",
                "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is",
                "there'd": "there would", "there'd've": "there would have", "there's": "there is", "here's": "here is",
                "they'd": "they would", "they'd've": "they would have", "they'll": "they will",
                "they'll've": "they will have", "they're": "they are", "they've": "they have", "to've": "to have",
                "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will",
                "we'll've": "we will have", "we're": "we are", "we've": "we have", "weren't": "were not",
                "what'll": "what will", "what'll've": "what will have", "what're": "what are", "what's": "what is",
                "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did",
                "where's": "where is", "where've": "where have", "who'll": "who will", "who'll've": "who will have",
                "who's": "who is", "who've": "who have", "why's": "why is", "why've": "why have",
                "will've": "will have", "won't": "will not", "won't've": "will not have", "would've": "would have",
                "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all",
                "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are",
                "y'all've": "you all have","you'd": "you would", "you'd've": "you would have", "you'll": "you will",
                "you'll've": "you will have", "you're": "you are", "you've": "you have" }

# %%
def known_contractions(emb):
    known = []
    for contract in contractions:
        if contract in emb:
            known.append(contract)
    return known

# %%
print("- Known Contractions -")
print("  Glove:")
print(known_contractions(emb_glove))
# Out:
# - Known Contractions -
#   Glove:
# ["can't", "'cause", "didn't", "doesn't", "don't", "i'd", "i'll", "i'm", "i've", "it's", "ma'am", "o'clock", "that's", "you'll", "you're"]

# %% [markdown]
# Not a lot of contractions are known. (FastText knows none)
# > We use the map to replace them

# %%
def clean_contractions(text, mapping):
    specials = ['”', '´', '‘', '“', '’', '¨', '‛', "`"]
    for s in specials:
        text = text.replace(s, "'")
    text = ' '.join([mapping[t] if t in mapping else t for t in text.split(" ")])
    return text

# %%
df['treated_question'] = df['lowered_question'].progress_apply(lambda x: clean_contractions(x, contractions))
# Out:
# 100%|██████████| 1362492/1362492 [00:04<00:00, 279577.70it/s]

# %%
df['treated_question'].head()
# Out:
# 0    how did quebec nationalists see their province...
# 1    do you have an adopted dog, how would you enco...
# 2    why does velocity affect time? does velocity a...
# 3    how did otto von guericke used the magdeburg h...
# 4    can i convert montra helicon d to a mountain b...
# Name: treated_question, dtype: object

# %%
vocab = build_vocab(df['treated_question'])
print("Glove: ")
oov_glove = check_coverage(vocab, emb_glove)
# Out:
# Glove:
# Found embeddings for 30.630% of vocab
# Found embeddings for  88.563% of all text

# %% [markdown]
# ## Now, let us deal with special characters

# %%
# Get set of all no_alnum in dataset
tmp = []
for x in df.question_text:
    for c in x:
        if not c.isalnum():
            tmp.append(c)
for x in test.question_text:
    for c in x:
        if not c.isalnum():
            tmp.append(c)
puncs = set(tmp) - set(' ')
print(puncs)
# Out:
# {'%', 'ំ', '♨', '⎛', '?', '√', '∝', '„', '=', '̈́', '@', '◌', 'ौ', '−', '¨', 'া', '㏑', '£', '͗', '“', '–', 'ு', '\x10', '≈', '∩', '̢', 'ా', '▒', '̳', '\xad', '\x8d', '＝', '∆', '।', '̾', '̼', '✅', '̕', '\u202c', '்', 'ះ', '͔', '《', '↓', '̓', '¯', '્', '्', 'ุ', '̖', '\uf0d8', '‛', '̶', '\u2061', '₦', '∴', '̔', '̤', '{', '®', '̴', 'ั', 'ూ', '∂', 'ि', '*', 'ॄ', '͋', '∞', 'ा', 'ి', '͆', '̃', '・', '̒', '℃', '∖', '₊', '̦', '\x06', '~', '↑', '\x1b', "'", '^', '‘', '¡', '˜', '／', '്', '͑', '[', '⦁', '»', '❓', '☁', '∗', '∼', '̮', 'ோ', '̷', '͒', '‰', 'ા', '㏒', '∫', '̭', '\u200c', 'ை', 'ٌ', '€', 'ি', '∑', '่', 'ো', '̉', 'ู', '∛', '\x01', '…', '͡', '§', 'ା', '⚧', '̜', 'ਾ', 'ॉ', '′', '͎', '⟨', '̈', '<', '？', '}', 'ు', '✔', 'ਿ', 'ี', '、', 'ं', '#', '－', '̽', '\u200e', '̌', '∈', 'ா', 'े', 'ी', '\x13', 'ੁ', '÷', '♡', '，', '̀', '〗', '_', '＄', '†', '¬', '̱', '͘', '⎞', '¸', '\u202a', ')', 'ీ', '\\', '´', '̘', 'ֿ', '⬇', '×', '▾', '⁻', '⊆', '→', 'ិ', 'ৃ', '̑', '̵', 'ّ', '̹', '/', '้', '\u200f', 'ः', '͈', '∡', '$', '़', '∘', '➡', '☹', '̗', '!', 'ْ', '‑', '́', 'ਂ', '̲', '\ufeff', '¿', '©', '⧽', 'ാ', 'ो', 'ា', '⟩', 'ृ', '͂', '’', '•', ';', '̧', '♏', 'ం', ',', '⧼', '᾽', '☺', '》', '️', '̰', '̅', '✌', '\xa0', '\u2060', '̆', '\x9d', '̥', '☝', 'ॢ', 'ូ', 'ി', '₩', '◦', '∅', '⌚', '্', '⋯', '˚', '؟', '਼', '≥', '⇒', '✏', '\x17', '́', '្', '™', '「', 'ॣ', '❤', 'ു', '͖', '\x03', '│', '˂', '✓', 'ͅ', '♀', 'ে', '⎠', '∠', '-', '‐', '᠌', '়', '¦', '♭', '>', '̺', '&', '″', '⊂', 'ী', '̞', '\x7f', '̿', 'ં', 'ै', 'ొ', '∇', '⃗', '̩', '¢', '«', '—', '\ue019', '͊', '͛', '`', '|', '͇', '̍', 'َ', '≠', '̂', '+', '」', '̊', '！', '☉', 'ௌ', 'ಾ', '\x92', ']', '〖', '̪', '♣', '̛', '.', '￼', '₹', '”', '̬', '＞', '͜', '̋', '\uf02d', 'ु', '\ue01b', '͚', ':', '︠', '̡', '\u200b', '∀', '̙', 'ੰ', '్', '∨', '；', 'ँ', '̫', '̎', '⊨', '̸', '·', 'ె', '،', '⋅', '(', 'ೋ', 'ು', '℅', 'ៃ', '¶', '͕', '̯', '︡', '\x02', '）', 'ੀ', '͝', '̝', '\x1a', '。', '⊥', '°', '＾', 'ِ', '≅', '¥', '（', '₱', '"', '≡', '̐', '͌', '△', 'ើ', '್', '∧', '⎝', '̻', '±', 'ி', 'ಿ', '∪', '͐', '≱', '̣', '̟', '≤', '͠', '͉', '̓', '̄', '\n', '̚', 'ី', '：', '̀', 'ू', '\x8f'}

# %%
# Get set of all no_alpha in dataset
tmp = []
for x in df.question_text:
    for c in x:
        if not c.isalpha():
            tmp.append(c)
for x in test.question_text:
    for c in x:
        if not c.isalpha():
            tmp.append(c)
no_alpha = set(tmp) - set(' ')
print(no_alpha)
# Out:
# {'%', 'ំ', '♨', '⎛', '?', '√', '∝', '„', '=', '̈́', '@', '◌', 'ौ', '−', '¨', 'া', '㏑', '£', '2', '͗', '“', '–', 'ு', '\x10', '≈', '∩', '̢', '⁸', 'ా', '▒', '̳', '\xad', '\x8d', '＝', '२', '∆', '।', '̾', '̼', '✅', '̕', '6', '₃', '\u202c', '்', 'ះ', '͔', '《', '↓', '̓', '¯', '્', '्', 'ุ', '̖', '\uf0d8', '‛', '4', '̶', '\u2061', '₦', '∴', '̔', '̤', '{', '®', '̴', 'ั', 'ూ', '∂', 'ि', '*', 'ॄ', '¼', '͋', '∞', 'ा', 'ి', '͆', '9', '̃', '・', '̒', '℃', '∖', '₊', '̦', '\x06', '~', '↑', '\x1b', "'", '^', '‘', '¡', '˜', '／', '്', '͑', '[', '⦁', '»', '❓', '☁', '∗', '∼', '̮', 'ோ', '̷', '͒', '‰', 'ા', '㏒', '∫', '̭', '\u200c', 'ை', 'ٌ', '€', 'ি', '∑', '่', 'ো', '̉', 'ู', '∛', '\x01', '…', '͡', '§', 'ା', '⚧', '̜', 'ਾ', 'ॉ', '′', '͎', '⟨', '̈', '<', '？', '}', 'ు', '✔', 'ਿ', 'ี', '³', '、', 'ं', '#', '－', '̽', '\u200e', '̌', '∈', 'ா', 'े', 'ी', '\x13', 'ੁ', '÷', '♡', '，', '̀', '〗', '₆', '_', '＄', '†', '¬', '̱', '͘', '⎞', '¸', '\u202a', '₁', ')', 'ీ', '\\', '´', '̘', 'ֿ', '⬇', '×', '▾', '⁻', '⁷', '⊆', '→', 'ិ', '¾', 'ৃ', '̑', '̵', '⁵', 'ّ', '̹', '/', '้', '\u200f', '½', 'ः', '͈', '∡', '$', '़', '∘', '➡', '☹', '̗', '!', 'ْ', '‑', '́', 'ਂ', '̲', '\ufeff', '¿', '©', '⧽', 'ാ', 'ो', '₄', 'ា', '⟩', 'ृ', '͂', '’', '•', ';', '̧', '♏', 'ం', ',', '⧼', '᾽', '☺', '》', '️', '̰', '̅', '✌', '\xa0', '\u2060', '̆', '\x9d', '̥', '☝', 'ॢ', 'ូ', '〇', 'ി', '₩', '◦', '∅', '⌚', '্', '٨', '0', '⋯', '˚', '؟', '਼', '≥', '⇒', '✏', '\x17', '́', '្', '™', '「', 'ॣ', '❤', 'ു', '͖', '\x03', '│', '˂', '✓', 'ͅ', '♀', 'ে', '⎠', '∠', '-', '‐', '᠌', '়', '¦', '♭', '>', '̺', '&', '″', '⊂', 'ী', '̞', '\x7f', '̿', '5', 'ં', 'ै', 'ొ', '∇', '⃗', '̩', '¢', '«', '—', '\ue019', '͊', '͛', '`', '|', '͇', '̍', '7', 'َ', '≠', '̂', '⅔', '+', '1', '」', '̊', '！', '☉', 'ௌ', 'ಾ', '₂', '\x92', ']', '〖', '̪', '♣', '̛', '8', '.', '￼', '₹', '”', '̬', '²', '＞', '⁰', '͜', '̋', '\uf02d', 'ु', '\ue01b', '͚', ':', '₅', '︠', '̡', '\u200b', '∀', '̙', 'ੰ', '⁴', '్', '∨', '；', 'ँ', '̎', '⊨', '̫', '̸', '·', 'ె', '،', '⋅', '(', 'ೋ', '⅓', 'ು', '℅', 'ៃ', '¶', '͕', '̯', '︡', '\x02', '）', 'ੀ', '͝', '̝', '\x1a', '。', '⊥', '°', '＾', 'ِ', '≅', '¥', '（', '₱', '"', '3', '≡', '̐', '͌', '△', 'ើ', '್', '⁶', '∧', '⎝', '̻', '±', 'ி', 'ಿ', '∪', '͐', '¹', '≱', '̣', '̟', '≤', '͠', '͉', '̓', '̄', '\n', '̚', 'ី', '：', '̀', 'ू', '\x8f'}

# %%
def unknown_punc(emb, puncs):
    unknown = ''
    for p in puncs:
        if p not in emb:
            unknown += f'"{p}": "", '
    return '{' + unknown + '}'

# %%
print("Glove: ")
print(unknown_punc(emb_glove, puncs))
print(unknown_punc(emb_glove, no_alpha))
# Out:
# Glove:
# {"ំ": "", "♨": "", "⎛": "", "√": "", "∝": "", "„": "", "̈́": "", "◌": "", "ौ": "", "−": "", "¨": "", "া": "", "㏑": "", "£": "", "͗": "", "“": "", "–": "", "ு": "", "": "", "≈": "", "∩": "", "̢": "", "ా": "", "▒": "", "̳": "", "­": "", "": "", "＝": "", "∆": "", "।": "", "̾": "", "̼": "", "✅": "", "̕": "", "‬": "", "்": "", "ះ": "", "͔": "", "《": "", "↓": "", "̓": "", "¯": "", "્": "", "्": "", "ุ": "", "̖": "", "": "", "‛": "", "̶": "", "⁡": "", "₦": "", "∴": "", "̔": "", "̤": "", "®": "", "̴": "", "ั": "", "ూ": "", "∂": "", "ि": "", "ॄ": "", "͋": "", "∞": "", "ा": "", "ి": "", "͆": "", "̃": "", "・": "", "̒": "", "℃": "", "∖": "", "₊": "", "̦": "", "": "", "↑": "", "": "", "‘": "", "¡": "", "˜": "", "／": "", "്": "", "͑": "", "⦁": "", "»": "", "❓": "", "☁": "", "∗": "", "∼": "", "̮": "", "ோ": "", "̷": "", "͒": "", "‰": "", "ા": "", "㏒": "", "∫": "", "̭": "", "‌": "", "ை": "", "ٌ": "", "€": "", "ি": "", "∑": "", "่": "", "ো": "", "̉": "", "ู": "", "∛": "", "": "", "…": "", "͡": "", "§": "", "ା": "", "⚧": "", "̜": "", "ਾ": "", "ॉ": "", "′": "", "͎": "", "⟨": "", "̈": "", "？": "", "ు": "", "✔": "", "ਿ": "", "ี": "", "、": "", "ं": "", "－": "", "̽": "", "‎": "", "̌": "", "∈": "", "ா": "", "े": "", "ी": "", "": "", "ੁ": "", "÷": "", "♡": "", "，": "", "̀": "", "〗": "", "＄": "", "†": "", "¬": "", "̱": "", "͘": "", "⎞": "", "¸": "", "‪": "", "ీ": "", "´": "", "̘": "", "ֿ": "", "⬇": "", "×": "", "▾": "", "⁻": "", "⊆": "", "→": "", "ិ": "", "ৃ": "", "̑": "", "̵": "", "ّ": "", "̹": "", "้": "", "‏": "", "ः": "", "͈": "", "∡": "", "़": "", "∘": "", "➡": "", "☹": "", "̗": "", "ْ": "", "‑": "", "́": "", "ਂ": "", "̲": "", "﻿": "", "¿": "", "©": "", "⧽": "", "ാ": "", "ो": "", "ា": "", "⟩": "", "ृ": "", "͂": "", "’": "", "•": "", "̧": "", "♏": "", "ం": "", "⧼": "", "᾽": "", "☺": "", "》": "", "️": "", "̰": "", "̅": "", "✌": "", " ": "", "⁠": "", "̆": "", "": "", "̥": "", "☝": "", "ॢ": "", "ូ": "", "ി": "", "₩": "", "◦": "", "∅": "", "⌚": "", "্": "", "⋯": "", "˚": "", "؟": "", "਼": "", "≥": "", "⇒": "", "✏": "", "": "", "́": "", "្": "", "™": "", "「": "", "ॣ": "", "❤": "", "ു": "", "͖": "", "": "", "│": "", "˂": "", "✓": "", "ͅ": "", "♀": "", "ে": "", "⎠": "", "∠": "", "‐": "", "᠌": "", "়": "", "¦": "", "♭": "", "̺": "", "″": "", "⊂": "", "ী": "", "̞": "", "": "", "̿": "", "ં": "", "ै": "", "ొ": "", "∇": "", "⃗": "", "̩": "", "¢": "", "«": "", "—": "", "": "", "͊": "", "͛": "", "͇": "", "̍": "", "َ": "", "≠": "", "̂": "", "」": "", "̊": "", "！": "", "☉": "", "ௌ": "", "ಾ": "", "": "", "〖": "", "̪": "", "♣": "", "̛": "", "￼": "", "₹": "", "”": "", "̬": "", "＞": "", "͜": "", "̋": "", "": "", "ु": "", "": "", "͚": "", "︠": "", "̡": "", "​": "", "∀": "", "̙": "", "ੰ": "", "్": "", "∨": "", "；": "", "ँ": "", "̫": "", "̎": "", "⊨": "", "̸": "", "·": "", "ె": "", "،": "", "⋅": "", "ೋ": "", "ು": "", "℅": "", "ៃ": "", "¶": "", "͕": "", "̯": "", "︡": "", "": "", "）": "", "ੀ": "", "͝": "", "̝": "", "": "", "。": "", "⊥": "", "°": "", "＾": "", "ِ": "", "≅": "", "¥": "", "（": "", "₱": "", "≡": "", "̐": "", "͌": "", "△": "", "ើ": "", "್": "", "∧": "", "⎝": "", "̻": "", "±": "", "ி": "", "ಿ": "", "∪": "", "͐": "", "≱": "", "̣": "", "̟": "", "≤": "", "͠": "", "͉": "", "̓": "", "̄": "", "
# ": "", "̚": "", "ី": "", "：": "", "̀": "", "ू": "", "": "", }
# {"ំ": "", "♨": "", "⎛": "", "√": "", "∝": "", "„": "", "̈́": "", "◌": "", "ौ": "", "−": "", "¨": "", "া": "", "㏑": "", "£": "", "͗": "", "“": "", "–": "", "ு": "", "": "", "≈": "", "∩": "", "̢": "", "⁸": "", "ా": "", "▒": "", "̳": "", "­": "", "": "", "＝": "", "२": "", "∆": "", "।": "", "̾": "", "̼": "", "✅": "", "̕": "", "₃": "", "‬": "", "்": "", "ះ": "", "͔": "", "《": "", "↓": "", "̓": "", "¯": "", "્": "", "्": "", "ุ": "", "̖": "", "": "", "‛": "", "̶": "", "⁡": "", "₦": "", "∴": "", "̔": "", "̤": "", "®": "", "̴": "", "ั": "", "ూ": "", "∂": "", "ि": "", "ॄ": "", "¼": "", "͋": "", "∞": "", "ा": "", "ి": "", "͆": "", "̃": "", "・": "", "̒": "", "℃": "", "∖": "", "₊": "", "̦": "", "": "", "↑": "", "": "", "‘": "", "¡": "", "˜": "", "／": "", "്": "", "͑": "", "⦁": "", "»": "", "❓": "", "☁": "", "∗": "", "∼": "", "̮": "", "ோ": "", "̷": "", "͒": "", "‰": "", "ા": "", "㏒": "", "∫": "", "̭": "", "‌": "", "ை": "", "ٌ": "", "€": "", "ি": "", "∑": "", "่": "", "ো": "", "̉": "", "ู": "", "∛": "", "": "", "…": "", "͡": "", "§": "", "ା": "", "⚧": "", "̜": "", "ਾ": "", "ॉ": "", "′": "", "͎": "", "⟨": "", "̈": "", "？": "", "ు": "", "✔": "", "ਿ": "", "ี": "", "³": "", "、": "", "ं": "", "－": "", "̽": "", "‎": "", "̌": "", "∈": "", "ா": "", "े": "", "ी": "", "": "", "ੁ": "", "÷": "", "♡": "", "，": "", "̀": "", "〗": "", "₆": "", "＄": "", "†": "", "¬": "", "̱": "", "͘": "", "⎞": "", "¸": "", "‪": "", "₁": "", "ీ": "", "´": "", "̘": "", "ֿ": "", "⬇": "", "×": "", "▾": "", "⁻": "", "⁷": "", "⊆": "", "→": "", "ិ": "", "¾": "", "ৃ": "", "̑": "", "̵": "", "⁵": "", "ّ": "", "̹": "", "้": "", "‏": "", "½": "", "ः": "", "͈": "", "∡": "", "़": "", "∘": "", "➡": "", "☹": "", "̗": "", "ْ": "", "‑": "", "́": "", "ਂ": "", "̲": "", "﻿": "", "¿": "", "©": "", "⧽": "", "ാ": "", "ो": "", "₄": "", "ា": "", "⟩": "", "ृ": "", "͂": "", "’": "", "•": "", "̧": "", "♏": "", "ం": "", "⧼": "", "᾽": "", "☺": "", "》": "", "️": "", "̰": "", "̅": "", "✌": "", " ": "", "⁠": "", "̆": "", "": "", "̥": "", "☝": "", "ॢ": "", "ូ": "", "〇": "", "ി": "", "₩": "", "◦": "", "∅": "", "⌚": "", "্": "", "٨": "", "⋯": "", "˚": "", "؟": "", "਼": "", "≥": "", "⇒": "", "✏": "", "": "", "́": "", "្": "", "™": "", "「": "", "ॣ": "", "❤": "", "ു": "", "͖": "", "": "", "│": "", "˂": "", "✓": "", "ͅ": "", "♀": "", "ে": "", "⎠": "", "∠": "", "‐": "", "᠌": "", "়": "", "¦": "", "♭": "", "̺": "", "″": "", "⊂": "", "ী": "", "̞": "", "": "", "̿": "", "ં": "", "ै": "", "ొ": "", "∇": "", "⃗": "", "̩": "", "¢": "", "«": "", "—": "", "": "", "͊": "", "͛": "", "͇": "", "̍": "", "َ": "", "≠": "", "̂": "", "⅔": "", "」": "", "̊": "", "！": "", "☉": "", "ௌ": "", "ಾ": "", "₂": "", "": "", "〖": "", "̪": "", "♣": "", "̛": "", "￼": "", "₹": "", "”": "", "̬": "", "²": "", "＞": "", "⁰": "", "͜": "", "̋": "", "": "", "ु": "", "": "", "͚": "", "₅": "", "︠": "", "̡": "", "​": "", "∀": "", "̙": "", "ੰ": "", "⁴": "", "్": "", "∨": "", "；": "", "ँ": "", "̎": "", "⊨": "", "̫": "", "̸": "", "·": "", "ె": "", "،": "", "⋅": "", "ೋ": "", "⅓": "", "ು": "", "℅": "", "ៃ": "", "¶": "", "͕": "", "̯": "", "︡": "", "": "", "）": "", "ੀ": "", "͝": "", "̝": "", "": "", "。": "", "⊥": "", "°": "", "＾": "", "ِ": "", "≅": "", "¥": "", "（": "", "₱": "", "≡": "", "̐": "", "͌": "", "△": "", "ើ": "", "್": "", "⁶": "", "∧": "", "⎝": "", "̻": "", "±": "", "ி": "", "ಿ": "", "∪": "", "͐": "", "¹": "", "≱": "", "̣": "", "̟": "", "≤": "", "͠": "", "͉": "", "̓": "", "̄": "", "
# ": "", "̚": "", "ី": "", "：": "", "̀": "", "ू": "", "": "", }

# %% [markdown]
# Some characters are unknown.
# > We use a map to replace unknown characters with known ones.
#
# > We make sure there are spaces between words and punctuation

# %%
punc_mapping = {"ँ": "", "◦": "", "̆": "", "✏": "", "": "", "ี": "", "♡": "o", "△": "", "⇒": "",
                 "": "", "＄": " dollar ", "∛": " sqrt ", "→": "", "͚": "", "️": "", "⟩": "", "¡": "i", "∴": " so ",
                 "್": "", "‬": "", "̘": "", "ា": "", "¿": "?", "⧼": "", "": "", "®": " r ", "∫": " calculus ",
                 "ौ": "", "∼": "", "َ": "", "ూ": "", "”": "'", "̙": "", "⋅": "", "̷": "", "̓": "",
                 "、": "", "⬇": "", "̔": "", "∗": "*", "͕": "", "͡": "", "̿": "", "‌": "", "͜": "", "̦": "",
                 "": "", "♨": "", "̮": "", "✓": " sqrt ", "ௌ": "", "»": " ", "➡": "", "̼": "", "̌": "",
                 "̢": "", "？": "?", "": "", "ৃ": "", "ం": "", "⊥": "", "̧": "", "ਾ": "", "》": " ",
                 "ਂ": "", "ិ": "", "∨": "", "ী": "", "े": "", "⧽": "", "⁡": "", "∀": " any ", "ु": "",
                 "ٌ": "", "₦": " naira ", "∡": " angle ", "̸": "", "़": "", "̃": "", "": "", "͎": "", "∧": "", "，": "",
                 "÷": "/", "،": "", "↓": "", "✔": "", "∩": " intersection ", "⁠": "", "¶": "", "ೋ": "", "͖": "",
                 "ে": "", "☝": "", "«": " ", "": "", "ं": "", "《": " ", "ॉ": "", "）": "", "͉": "",
                 "⟨": "", "": "", "ْ": "", "‏": "", "₱": " peso ", "°": "", "͋": "", "✌": "", "্": "", "᠌": "",
                 "♣": "", "×": "x", "ো": "", "؟": "?", "˜": "", "̩": "", "̱": "", "̺": "", "͔": "",
                 "▾": "", "⎛": "", "ొ": "", "்": "", "̊": "", "̥": "", "ੁ": "", "่": "", "﻿": "", "˚": "",
                 "㏒": " log ", "ా": "", "ા": "", "™": " tm ", "ِ": "", "∈": "", "⃗": "", "≅": "=", "̵": "", "♭": "",
                 "ಾ": "", "；": ".", "̒": "", "ி": "", "´": "'", "＞": ">", "̣": "", "ุ": "", "ّ": "", "▒": "",
                 "।": "", "–": "-", "∖": "", "̰": "", "ॄ": "", "‘": "'", "̶": "-", "ो": "", "！": "!", "☺": "",
                 "̎": "", "″": "", "＝": "=", "˂": "", "਼": "", "ः": "", "ֿ": "", "♏": "", "¦": "", "̝": "",
                 "∪": " union ", "̈": "", "́": "", "‐": "-", "“": "'", "ാ": "", "≤": "<=", "ੀ": "", "": "", "\n": "",
                 "◌": "", "§": "", "ृ": "", "ு": "", "ा": "", "√": " sqrt ", "¥": " yen ", "‑": "-", "￼": "", "": "",
                 "्": "", "̭": "", "": "", "¬": "", "͌": "", "̍": "", "„": "", "ី": "", "•": "", "↑": "",
                 "͘": "", "": "", "͇": "", "̫": "", "ா": "", "͛": "", "︠": "", "⁻": "-", "᾽": "", "ি": "",
                 "̟": "", "│": "|", "̕": "", "͊": "", "∠": " angle ", "̑": "", "‎": "", "㏑": " ln ", "☁": "", "ಿ": "",
                 "ी": "", "̀": "", "়": "", "̐": "", "☉": "", "": "", "⚧": "", "£": " pound ", "・": "", "⋯": "...",
                 "−": "-", "∅": " ", "¸": ",", "̋": "", "̲": "", "⎝": "", "͆": "", "〗": "]", "／": "", "ั": "",
                 "：": "", "ோ": "", "̽": "", "∑": " sum ", "©": " c ", "": "", "്": "", "ು": "", "ు": "", "్": "",
                 "∞": " infinity ", "ि": "", "⊨": "", "̈́": "", "̚": "", "̖": "", "̡": "", "⊆": "", "·": ".", "✅": "",
                 "ͅ": "", "ੰ": "", "̾": "", "…": "", "＾": "^", "≈": "=", "—": "-", "♀": "", "❤": "", "્": "",
                 "ା": "", "¢": "", "⎞": "", "ె": "", "​": "", "̻": "", "（": "", "‪": "", "≠": "!=", "ॢ": "",
                 "ં": "", "〖": "[", "­": "", "∂": "", "̬": "", "͐": "", "": "", "₊": "+", "℅": "%", "̛": "",
                 "‰": "", "ਿ": "", "͈": "", "́": "", "͂": "", "̞": "", "ి": "", "้": "", "̗": "", "ു": "",
                 "": "", "’": "'", "া": "", "ើ": "", "": "", "ះ": "", "」": "]", "︡": "", "ू": "",
                 "̳": "", "ை": "", "⊂": "", "∇": "", "≥": ">=", "̄": "", "₹": " e ", "̜": "", "̴": "",
                 "℃": "", "±": "+", "⌚": " time ", "≡": "", "̹": "", "̯": "", "′": "", "ీ": "", "ូ": "", "－": " ",
                 "「": "[", "̀": "", "¨": "'", "ॣ": "", "⦁": "", "€": " euro ", "❓": "?", "ู": "", "͗": "", "̅": "",
                 "̂": "", "͠": "", "̤": "", "្": "", "̉": "", "₩": "", "": "", "̪": "", "ै": "", "∘": "",
                 "ៃ": "", "͑": "", "ំ": "", "͒": "", "☹": "", "͝": "", "‛": "'", "⎠": "", "¯": "", "。": ".",
                 "∆": "", "ി": "", "̓": "", "∝": "", "†": "", "≱": "", "²": "2", 'θ': 'theta', "`": "'",
                 'α': 'alpha', 'à': 'a', 'β': 'beta', '³': '3', 'π': 'pi', "₁": "1", "₃": "3", "₆": "6", "¼": "1/4",
                 "⁷": "7", "¾": "3/4", "⁵": "5", "₅": "5", "½": "1/2", "₄": "4", "⅔": "2/3", "₂": "2", "¹": "1"}

# %%
single_quote = [k for k in punc_mapping if punc_mapping[k] == "'"]
print(single_quote)
# Out:
# ['”', '´', '‘', '“', '’', '¨', '‛', '`']

# %%
punc_re = re.compile('(%s)' % '|'.join(punc_mapping.keys()))
def replace_punc(text):
    def replace(match):
        return punc_mapping[match.group(0)]
    return punc_re.sub(replace, text)

def sep_punc(x):
    for p in puncs:
        x = x.replace(p, f' {p} ')
    return x

def clean_special_chars(text, punc, mapping):
    for p in mapping:
        text = text.replace(p, mapping[p])
    for p in punc:
        text = text.replace(p, f' {p} ')
    return text

# %%
df['treated_question'] = df['treated_question'].progress_apply(lambda x: clean_special_chars(x, puncs, punc_mapping))
# 以下两步和 clean_special_chars 功能一样，但是效果不如 clean_special_chars，有待验证
# df['treated_question'] = df['treated_question'].progress_apply(lambda x: replace_punc(x))
# df['treated_question'] = df['treated_question'].progress_apply(lambda x: sep_punc(x))
# Out:
# 100%|██████████| 1362492/1362492 [02:25<00:00, 9351.20it/s]

# %%
vocab = build_vocab(df['treated_question'])
print("Glove: ")
oov_glove = check_coverage(vocab, emb_glove)
# Out:
# Glove:
# Found embeddings for 69.213% of vocab
# Found embeddings for  99.579% of all text

# %%
print(len(oov_glove))
oov_glove[:1000]
# Out:
# 61581
# [('quorans', 885),
#  ('brexit', 542),
#  ('cryptocurrencies', 525),
#  ('redmi', 398),
#  ('coinbase', 150),
#  ('oneplus', 144),
#  ('uceed', 126),
#  ('demonetisation', 118),
#  ('bhakts', 118),
#  ('upwork', 117),
#  ('pokémon', 117),
#  ('machedo', 112),
#  ('gdpr', 110),
#  ('adityanath', 108),
#  ('bnbr', 105),
#  ('boruto', 105),
#  ('alshamsi', 100),
#  ('dceu', 94),
#  ('iiest', 91),
#  ('litecoin', 90),
#  ('unacademy', 89),
#  ('sjws', 89),
#  ('zerodha', 85),
#  ('qoura', 85),
#  ('tensorflow', 82),
#  ('fiancé', 76),
#  ('lnmiit', 73),
#  ('kavalireddi', 71),
#  ('doklam', 70),
#  ('muoet', 68),
#  ('nicmar', 66),
#  ('vajiram', 62),
#  ('srmjee', 61),
#  ('adhaar', 60),
#  ('altcoin', 59),
#  ('zebpay', 58),
#  ('elitmus', 58),
#  ('jiren', 56),
#  ('altcoins', 56),
#  ('awdhesh', 55),
#  ('hackerrank', 54),
#  ('ryzen', 51),
#  ('koinex', 50),
#  ('baahubali', 48),
#  ('mhcet', 47),
#  ('byju', 47),
#  ('binance', 46),
#  ('srmjeee', 44),
#  ('beerus', 43),
#  ('ftre', 42),
#  ('skripal', 42),
#  ('sgsits', 42),
#  ('mhtcet', 40),
#  ('hotstar', 40),
#  ('gurugram', 40),
#  ('bipc', 39),
#  ('lbsnaa', 38),
#  ('bmsce', 38),
#  ('jiofi', 38),
#  ('nanodegree', 38),
#  ('sarahah', 36),
#  ('ravula', 36),
#  ('microservices', 36),
#  ('swachh', 36),
#  ('obor', 35),
#  ('usict', 34),
#  ('patreon', 34),
#  ('reactjs', 34),
#  ('clickbait', 34),
#  ('zenfone', 33),
#  ('iisers', 33),
#  ('bittrex', 32),
#  ('chromecast', 32),
#  ('pessat', 31),
#  ('jungkook', 30),
#  ('xxxtentacion', 30),
#  ('dream11', 30),
#  ('demonitisation', 30),
#  ('kalpit', 29),
#  ('bitconnect', 29),
#  ('mmmut', 29),
#  ('aktu', 29),
#  ('deepmind', 28),
#  ('airpods', 28),
#  ('trumpcare', 28),
#  ('onedrive', 27),
#  ('rlwl', 27),
#  ('aiats', 27),
#  ('hbtu', 26),
#  ('zamasu', 26),
#  ('codeforces', 26),
#  ('wannacry', 26),
#  ('irodov', 25),
#  ('despacito', 25),
#  ('simpliv', 25),
#  ('são', 25),
#  ('nlus', 25),
#  ('vssut', 25),
#  ('electroneum', 24),
#  ('fz25', 24),
#  ('chapterwise', 24),
#  ('arrowverse', 24),
#  ('lnct', 24),
#  ('kubernetes', 24),
#  ('iiitd', 23),
#  ('eflu', 23),
#  ('igdtuw', 23),
#  ('genderfluid', 23),
#  ('kovind', 23),
#  ('iiith', 23),
#  ('whydo', 23),
#  ('internshala', 23),
#  ('makaut', 22),
#  ('zhihu', 22),
#  ('undertale', 22),
#  ('padmavat', 22),
#  ('twinflame', 22),
#  ('ravindrababu', 22),
#  ('incels', 22),
#  ('ncerts', 22),
#  ('undergraduation', 22),
#  ('josé', 22),
#  ('padmaavat', 22),
#  ('hackerearth', 21),
#  ('fiancée', 21),
#  ('veerwal', 21),
#  ('remainers', 21),
#  ('byjus', 21),
#  ('schizoids', 21),
#  ('extc', 21),
#  ('overbrace', 21),
#  ('vitee', 21),
#  ('jcpoa', 21),
#  ('blockchains', 21),
#  ('xiomi', 21),
#  ('cos2x', 21),
#  ('tissnet', 21),
#  ('apist', 21),
#  ('ifos', 20),
#  ('theranos', 20),
#  ('pizzagate', 20),
#  ('ipmat', 20),
#  ('odoo', 20),
#  ('pmay', 20),
#  ('covfefe', 19),
#  ('strzok', 19),
#  ('kaneki', 19),
#  ('dhinchak', 19),
#  ('clichés', 19),
#  ('beyoncé', 19),
#  ('awdesh', 19),
#  ('yourquote', 19),
#  ('steemit', 19),
#  ('wikitribune', 19),
#  ('fullform', 19),
#  ('bitfinex', 18),
#  ('iihm', 18),
#  ('déja', 18),
#  ('drumpf', 18),
#  ('d3300', 18),
#  ('ailet', 18),
#  ('sscbs', 18),
#  ('atatürk', 17),
#  ('hsee', 17),
#  ('kgmu', 17),
#  ('mbappe', 17),
#  ('lhmc', 17),
#  ('करन', 17),
#  ('1300d', 17),
#  ('kattankulathur', 17),
#  ('instacart', 17),
#  ('bmsit', 17),
#  ('jupyter', 17),
#  ('qidian', 17),
#  ('क', 17),
#  ('erdoğan', 17),
#  ('aieea', 16),
#  ('ह', 16),
#  ('neuralink', 16),
#  ('class11', 16),
#  ('940mx', 16),
#  ('usaco', 16),
#  ('mobikwik', 16),
#  ('whyis', 16),
#  ('2k17', 16),
#  ('warmbier', 16),
#  ('upeseat', 16),
#  ('rgipt', 16),
#  ('pgdbf', 16),
#  ('taehyung', 16),
#  ('nitians', 16),
#  ('msqe', 16),
#  ('doordash', 16),
#  ('nsejs', 16),
#  ('pesu', 16),
#  ('ahok', 16),
#  ('homepod', 16),
#  ('kainerugaba', 16),
#  ('fitjee', 15),
#  ('flipcart', 15),
#  ('minance', 15),
#  ('vitmee', 15),
#  ('160r', 15),
#  ('igst', 15),
#  ('hashflare', 15),
#  ('toppr', 15),
#  ('feku', 15),
#  ('2k18', 15),
#  ('ipucet', 15),
#  ('ω', 15),
#  ('openai', 15),
#  ('killmonger', 15),
#  ('mh370', 15),
#  ('leetcode', 15),
#  ('françois', 15),
#  ('schrödinger', 15),
#  ('sayat', 15),
#  ('montréal', 15),
#  ('wumao', 14),
#  ('jiophone', 14),
#  ('unocoin', 14),
#  ('dogecoin', 14),
#  ('segwit2x', 14),
#  ('nluo', 14),
#  ('alphago', 14),
#  ('tamilans', 14),
#  ('freecodecamp', 14),
#  ('kefla', 14),
#  ('gstin', 14),
#  ('dsce', 14),
#  ('ipill', 14),
#  ('ugee', 14),
#  ('mh17', 14),
#  ('webnovel', 14),
#  ('demonitization', 14),
#  ('jecrc', 14),
#  ('brexiters', 14),
#  ('plancess', 14),
#  ('cliché', 14),
#  ('nielit', 14),
#  ('daesh', 14),
#  ('d7200', 14),
#  ('onecoin', 14),
#  ('ubereats', 14),
#  ('narcissit', 13),
#  ('musigma', 13),
#  ('angular2', 13),
#  ('phonepe', 13),
#  ('niftem', 13),
#  ('practo', 13),
#  ('opham', 13),
#  ('poloniex', 13),
#  ('iict', 13),
#  ('7700k', 13),
#  ('ballb', 13),
#  ('sppu', 13),
#  ('thé', 13),
#  ('digitalocean', 13),
#  ('aimcat', 13),
#  ('deplorables', 13),
#  ('zoomcar', 13),
#  ('covalency', 13),
#  ('waymo', 13),
#  ('imucet', 13),
#  ('lrdi', 13),
#  ('uppcs', 12),
#  ('kasganj', 12),
#  ('techmahindra', 12),
#  ('rené', 12),
#  ('gödel', 12),
#  ('trumpism', 12),
#  ('eu4', 12),
#  ('dilr', 12),
#  ('sanghis', 12),
#  ('δ', 12),
#  ('etoos', 12),
#  ('hyperconjugation', 12),
#  ('mpstme', 12),
#  ('1050ti', 12),
#  ('nearbuy', 12),
#  ('sklearn', 12),
#  ('iert', 12),
#  ('darkweb', 12),
#  ('brexiteers', 12),
#  ('bumrah', 12),
#  ('incel', 12),
#  ('rwby', 12),
#  ('tqwl', 12),
#  ('kilimall', 12),
#  ('hypsm', 12),
#  ('émile', 11),
#  ('rnsit', 11),
#  ('vesit', 11),
#  ('freebitco', 11),
#  ('rbei', 11),
#  ('erc20', 11),
#  ('class9', 11),
#  ('gdax', 11),
#  ('lenskart', 11),
#  ('d5300', 11),
#  ('pgdie', 11),
#  ('7200u', 11),
#  ('oliveboard', 11),
#  ('trezor', 11),
#  ('padmé', 11),
#  ('arkit', 11),
#  ('autoencoder', 11),
#  ('otsutsuki', 11),
#  ('fayol', 11),
#  ('rcoem', 11),
#  ('graphql', 11),
#  ('antminer', 11),
#  ('prmo', 11),
#  ('bartetzko', 11),
#  ('cooh', 11),
#  ('shippūden', 11),
#  ('simsree', 11),
#  ('webassembly', 11),
#  ('quoras', 11),
#  ('andré', 10),
#  ('datacamp', 10),
#  ('rnns', 10),
#  ('petuhov', 10),
#  ('madeeasy', 10),
#  ('cptsd', 10),
#  ('filecoin', 10),
#  ('igrua', 10),
#  ('gaslighter', 10),
#  ('thicc', 10),
#  ('alphazero', 10),
#  ('café', 10),
#  ('bstat', 10),
#  ('kgmc', 10),
#  ('etherum', 10),
#  ('λ', 10),
#  ('gujratis', 10),
#  ('gurmehar', 10),
#  ('bolsonaro', 10),
#  ('gaslighted', 10),
#  ('cph4', 10),
#  ('carplay', 10),
#  ('strowman', 10),
#  ('φ', 10),
#  ('testbook', 10),
#  ('cas9', 10),
#  ('pytorch', 10),
#  ('hololens', 10),
#  ('tambrahms', 10),
#  ('digilocker', 10),
#  ('oswaal', 10),
#  ('whydoes', 10),
#  ('xender', 10),
#  ('rakshaks', 10),
#  ('cringiest', 10),
#  ('ciaz', 10),
#  ('fnaf', 10),
#  ('iqoption', 10),
#  ('sense8', 10),
#  ('bschools', 10),
#  ('qyburn', 10),
#  ('ge14', 10),
#  ('siacoin', 10),
#  ('5lpa', 10),
#  ('whatapp', 10),
#  ('krennic', 10),
#  ('ns200', 10),
#  ('niccolò', 10),
#  ('d3400', 9),
#  ('k2cr2o7', 9),
#  ('doky', 9),
#  ('nitian', 9),
#  ('urbanclap', 9),
#  ('lpunest', 9),
#  ('gonzález', 9),
#  ('delloite', 9),
#  ('pmkvy', 9),
#  ('digibank', 9),
#  ('vistara', 9),
#  ('cotx', 9),
#  ('serbo', 9),
#  ('aimcats', 9),
#  ('azdome', 9),
#  ('neet2017', 9),
#  ('σ', 9),
#  ('wilp', 9),
#  ('got7', 9),
#  ('tspsc', 9),
#  ('narcisists', 9),
#  ('empowr', 9),
#  ('scoopwhoop', 9),
#  ('howdoes', 9),
#  ('bvcoe', 9),
#  ('debotosh', 9),
#  ('ditiss', 9),
#  ('tezos', 9),
#  ('midoriya', 9),
#  ('rejuvalex', 9),
#  ('ciwg', 9),
#  ('juit', 9),
#  ('frdi', 9),
#  ('a2as', 9),
#  ('gtbit', 9),
#  ('haptik', 9),
#  ('γ', 9),
#  ('bftech', 9),
#  ('nofap', 9),
#  ('1080ti', 9),
#  ('win10', 9),
#  ('aayog', 9),
#  ('fadnavis', 9),
#  ('alovera', 9),
#  ('gitlab', 9),
#  ('iiitdm', 9),
#  ('jnuee', 9),
#  ('jeemains', 9),
#  ('delhite', 9),
#  ('मर', 9),
#  ('touchbar', 9),
#  ('brontë', 9),
#  ('crytocurrency', 9),
#  ('suryanamaskar', 9),
#  ('vuejs', 9),
#  ('québec', 9),
#  ('baslp', 9),
#  ('indominus', 9),
#  ('bajjika', 9),
#  ('raúl', 8),
#  ('uncollapse', 8),
#  ('avenatti', 8),
#  ('sricity', 8),
#  ('rajyasabha', 8),
#  ('wishfie', 8),
#  ('clichéd', 8),
#  ('novichok', 8),
#  ('thighing', 8),
#  ('cocubes', 8),
#  ('iitkgp', 8),
#  ('8700k', 8),
#  ('hyperthymesia', 8),
#  ('dapps', 8),
#  ('naïve', 8),
#  ('islamaphobic', 8),
#  ('jeemain', 8),
#  ('tallentex', 8),
#  ('snapchats', 8),
#  ('antshares', 8),
#  ('lstms', 8),
#  ('sallery', 8),
#  ('coching', 8),
#  ('mangalyaan', 8),
#  ('sapiosexual', 8),
#  ('quorians', 8),
#  ('microservice', 8),
#  ('biromantic', 8),
#  ('philando', 8),
#  ('kygo', 8),
#  ('nmamit', 8),
#  ('mysuru', 8),
#  ('antardasha', 8),
#  ('misérables', 8),
#  ('jozwik', 8),
#  ('skripals', 8),
#  ('scripbox', 8),
#  ('2theta', 8),
#  ('fmge', 8),
#  ('sokovia', 8),
#  ('école', 8),
#  ('class12', 8),
#  ('vidyalankar', 8),
#  ('b1b2', 8),
#  ('fullstack', 8),
#  ('word2vec', 8),
#  ('stardew', 8),
#  ('umtiti', 8),
#  ('cosecx', 8),
#  ('cucet', 8),
#  ('digibyte', 8),
#  ('playerunknown', 8),
#  ('uttarpradesh', 8),
#  ('note4', 8),
#  ('insofe', 8),
#  ('worldquant', 8),
#  ('buildbox', 7),
#  ('pivx', 7),
#  ('preboards', 7),
#  ('elementor', 7),
#  ('terroristan', 7),
#  ('mangalapuram', 7),
#  ('nagerkovil', 7),
#  ('rgnul', 7),
#  ('blackpink', 7),
#  ('happeno', 7),
#  ('esp8266', 7),
#  ('yiannopolous', 7),
#  ('nitroaniline', 7),
#  ('jiménez', 7),
#  ('mvsr', 7),
#  ('techm', 7),
#  ('döner', 7),
#  ('hashgraph', 7),
#  ('deliveroo', 7),
#  ('rastra', 7),
#  ('syeds', 7),
#  ('1000rs', 7),
#  ('bathla', 7),
#  ('mevani', 7),
#  ('g4560', 7),
#  ('whatsaap', 7),
#  ('sairat', 7),
#  ('omscs', 7),
#  ('rmlnlu', 7),
#  ('blinkist', 7),
#  ('zürich', 7),
#  ('ı', 7),
#  ('pubdet', 7),
#  ('tenseigan', 7),
#  ('whivh', 7),
#  ('vantablack', 7),
#  ('gfrg', 7),
#  ('payumoney', 7),
#  ('myetherwallet', 7),
#  ('momoshiki', 7),
#  ('bimaru', 7),
#  ('centillion', 7),
#  ('fuckboys', 7),
#  ('991ms', 7),
#  ('dubsmash', 7),
#  ('nitc', 7),
#  ('psit', 7),
#  ('cryptocoin', 7),
#  ('manspreading', 7),
#  ('mewani', 7),
#  ('kejariwal', 7),
#  ('foodpanda', 7),
#  ('ghazwa', 7),
#  ('düsseldorf', 7),
#  ('cleartax', 7),
#  ('theeta', 7),
#  ('1crore', 7),
#  ('devasena', 7),
#  ('bluemix', 7),
#  ('gbwhatsapp', 7),
#  ('locopilot', 7),
#  ('trumpsters', 7),
#  ('mersal', 7),
#  ('izuku', 7),
#  ('y53', 7),
#  ('nidahas', 7),
#  ('puneri', 7),
#  ('garud', 7),
#  ('kekistan', 7),
#  ('uipath', 7),
#  ('tapzo', 7),
#  ('autoencoders', 7),
#  ('freshworks', 7),
#  ('ψ', 7),
#  ('dsatm', 7),
#  ('rautela', 7),
#  ('iitram', 7),
#  ('पर', 7),
#  ('म', 7),
#  ('thadomal', 7),
#  ('aghoris', 7),
#  ('jgls', 7),
#  ('gazwa', 7),
#  ('parmanu', 7),
#  ('isbf', 7),
#  ('nuals', 7),
#  ('bhallaladeva', 7),
#  ('polyhouse', 7),
#  ('madheshis', 7),
#  ('xvg', 7),
#  ('intenship', 7),
#  ('zcash', 7),
#  ('qtum', 7),
#  ('demonatisation', 7),
#  ('juicero', 7),
#  ('litecoins', 7),
#  ('juárez', 7),
#  ('satoshis', 7),
#  ('landran', 7),
#  ('upvoters', 7),
#  ('costheta', 7),
#  ('testdaf', 7),
#  ('randyll', 7),
#  ('igtv', 7),
#  ('sharudenko', 7),
#  ('ekyc', 7),
#  ('pgdhrm', 7),
#  ('xcent', 7),
#  ('ichange', 7),
#  ('westbengal', 7),
#  ('bregoli', 7),
#  ('nanoray', 7),
#  ('žižek', 7),
#  ('卐', 6),
#  ('lahren', 6),
#  ('ambarella', 6),
#  ('elxsi', 6),
#  ('venturimeter', 6),
#  ('sinb', 6),
#  ('bhumihar', 6),
#  ('baiyue', 6),
#  ('narcicist', 6),
#  ('commonapp', 6),
#  ('avpd', 6),
#  ('tenkasi', 6),
#  ('mukt', 6),
#  ('kgec', 6),
#  ('alshami', 6),
#  ('oberlo', 6),
#  ('brachistochrone', 6),
#  ('göring', 6),
#  ('991es', 6),
#  ('hindians', 6),
#  ('evion', 6),
#  ('malmö', 6),
#  ('workex', 6),
#  ('tuee', 6),
#  ('kersee', 6),
#  ('mechnovate', 6),
#  ('dcrust', 6),
#  ('hapnes', 6),
#  ('ssjb', 6),
#  ('iitjam', 6),
#  ('powerbanks', 6),
#  ('relu', 6),
#  ('offerup', 6),
#  ('paramhansha', 6),
#  ('xenoverse', 6),
#  ('iiitb', 6),
#  ('μ', 6),
#  ('ossoff', 6),
#  ('korotkevich', 6),
#  ('xgboost', 6),
#  ('staybay', 6),
#  ('lbsim', 6),
#  ('dmart', 6),
#  ('segwit', 6),
#  ('gateforum', 6),
#  ('sgtb', 6),
#  ('aimim', 6),
#  ('2lakhs', 6),
#  ('divyansh', 6),
#  ('kahoot', 6),
#  ('eastwatch', 6),
#  ('dentacoin', 6),
#  ('orthocentre', 6),
#  ('maría', 6),
#  ('iphone7', 6),
#  ('1mole', 6),
#  ('golgappa', 6),
#  ('blockstack', 6),
#  ('shifuji', 6),
#  ('antibrahmin', 6),
#  ('ōtsutsuki', 6),
#  ('nestaway', 6),
#  ('allincall', 6),
#  ('diprotic', 6),
#  ('h3po3', 6),
#  ('cryptocurreny', 6),
#  ('dichlorine', 6),
#  ('whyare', 6),
#  ('trignometric', 6),
#  ('mastuburation', 6),
#  ('freecharge', 6),
#  ('bakliwal', 6),
#  ('tfws', 6),
#  ('namikaze', 6),
#  ('remoaners', 6),
#  ('geometrifying', 6),
#  ('qué', 6),
#  ('geeksforgeeks', 6),
#  ('oversmart', 6),
#  ('openload', 6),
#  ('cuphead', 6),
#  ('rojava', 6),
#  ('muchhal', 6),
#  ('markiplier', 6),
#  ('edureka', 6),
#  ('fe3', 6),
#  ('6300hq', 6),
#  ('oumuamua', 6),
#  ('jio4gvoice', 6),
#  ('snapay', 6),
#  ('dimash', 6),
#  ('r558uq', 6),
#  ('xef6', 6),
#  ('vidmate', 6),
#  ('wakad', 6),
#  ('4xy', 6),
#  ('cryptocoins', 6),
#  ('trumpists', 6),
#  ('mélenchon', 6),
#  ('kissanime', 6),
#  ('fifa17', 6),
#  ('eindiawholesale', 6),
#  ('s7e7', 6),
#  ('kingroot', 6),
#  ('dujat', 6),
#  ('fasttext', 6),
#  ('amwf', 6),
#  ('laliga', 6),
#  ('iittm', 6),
#  ('hardhome', 6),
#  ('na2s2o3', 6),
#  ('tracxn', 6),
#  ('nitw', 6),
#  ('qspiders', 6),
#  ('niacl', 6),
#  ('caulifla', 6),
#  ('mvit', 6),
#  ('renée', 6),
#  ('toneri', 6),
#  ('etherparty', 6),
#  ('animoji', 6),
#  ('crytocurrencies', 6),
#  ('führer', 6),
#  ('spipa', 6),
#  ('resofast', 6),
#  ('xapo', 6),
#  ('nodemcu', 6),
#  ('लगन', 6),
#  ('bytecoin', 6),
#  ('phycopath', 6),
#  ('pyqt5', 6),
#  ('cryptocurency', 6),
#  ('garrix', 6),
#  ('vaporwave', 6),
#  ('electrovalent', 6),
#  ('edwisor', 6),
#  ('mstat', 6),
#  ('howdid', 6),
#  ('ios11', 6),
#  ('trumpian', 6),
#  ('pibm', 6),
#  ('possesiveness', 6),
#  ('chhillar', 6),
#  ('lmrc', 6),
#  ('tigor', 6),
#  ('sevmeyene', 6),
#  ('mpharm', 6),
#  ('aiactr', 6),
#  ('jgec', 6),
#  ('aksener', 6),
#  ('université', 6),
#  ('cac2', 5),
#  ('enchroma', 5),
#  ('résumé', 5),
#  ('namakharam', 5),
#  ('mitsom', 5),
#  ('tsicet', 5),
#  ('kattappa', 5),
#  ('lópez', 5),
#  ('pgpem', 5),
#  ('ffcs', 5),
#  ('rc200', 5),
#  ('protonmail', 5),
#  ('speedforce', 5),
#  ('dictorship', 5),
#  ('t6i', 5),
#  ('ukvi', 5),
#  ('rohinga', 5),
#  ('tanb', 5),
#  ('å', 5),
#  ('sickular', 5),
#  ('ppdt', 5),
#  ('hyps', 5),
#  ('methanoic', 5),
#  ('sin3x', 5),
#  ('कय', 5),
#  ('kolkey', 5),
#  ('howis', 5),
#  ('gearbest', 5),
#  ('kivy', 5),
#  ('cyrptocurrency', 5),
#  ('r15s', 5),
#  ('stayuncle', 5),
#  ('piwat', 5),
#  ('doscos', 5),
#  ('woxsen', 5),
#  ('bitmoji', 5),
#  ('iofs', 5),
#  ('prepation', 5),
#  ('bijwasan', 5),
#  ('pahul', 5),
#  ('ayog', 5),
#  ('icetratt', 5),
#  ('joão', 5),
#  ('u0001f914', 5),
#  ('vaxxers', 5),
#  ('demonitised', 5),
#  ('redme', 5),
#  ('humanties', 5),
#  ('odissa', 5),
#  ('h3po2', 5),
#  ('neduvasal', 5),
#  ('ramanujam', 5),
#  ('studienkolleg', 5),
#  ('shingrix', 5),
#  ('côte', 5),
#  ('nliu', 5),
#  ('altacoin', 5),
#  ('limeroad', 5),
#  ('icitss', 5),
#  ('pillani', 5),
#  ('iphone6', 5),
#  ('ⁿ', 5),
#  ('5cr', 5),
#  ('accolite', 5),
#  ('bakths', 5),
#  ('udan', 5),
#  ('spaghettification', 5),
#  ('katappa', 5),
#  ('songkhla', 5),
#  ('brasília', 5),
#  ('msruas', 5),
#  ('overcaring', 5),
#  ('garoppolo', 5),
#  ('wbpsc', 5),
#  ('thyronorm', 5),
#  ('openshift', 5),
#  ('bnys', 5),
#  ('mgtows', 5),
#  ('duplet', 5),
#  ('disapparate', 5),
#  ('varrier', 5),
#  ('anlamaz', 5),
#  ('त', 5),
#  ('resumé', 5),
#  ('superscore', 5),
#  ('6200u', 5),
#  ('econimics', 5),
#  ('mitid', 5),
#  ('katalon', 5),
#  ('liangelo', 5),
#  ('özil', 5),
#  ('tamoghna', 5),
#  ('asgardia', 5),
#  ('databricks', 5),
#  ('français', 5),
#  ('आन', 5),
#  ('3sin', 5),
#  ('quroa', 5),
#  ('weatern', 5),
#  ('addhar', 5),
#  ('curaçao', 5),
#  ('statergy', 5),
#  ('seq2seq', 5),
#  ('wbchse', 5),
#  ('c2h2', 5),
#  ('subnautica', 5),
#  ('एक', 5),
#  ('ramrahim', 5),
#  ('balayam', 5),
#  ('nseb', 5),
#  ('codevita', 5),
#  ('yondu', 5),
#  ('whtsapp', 5),
#  ('ellaria', 5),
#  ('pshycology', 5),
#  ('ntorq', 5),
#  ('7300hq', 5),
#  ('etmoney', 5),
#  ('miui9', 5),
#  ('bodnick', 5),
#  ('matram', 5),
#  ('mahadasa', 5),
#  ('b777', 5),
#  ('tanjavur', 5),
#  ('jiocoin', 5),
#  ('narcassist', 5),
#  ('hnlu', 5),
#  ('decofest', 5),
#  ('feminazism', 5),
#  ('gangrapes', 5),
#  ('chaiwala', 5),
#  ('mnlu', 5),
#  ('état', 5),
#  ('pixelbook', 5),
#  ('mutarotation', 5),
#  ('heilongjiang', 5),
#  ('interviewbit', 5),
#  ('mahishmati', 5),
#  ('méxico', 5),
#  ('cryptoassets', 5),
#  ('bíró', 5),
#  ('lászló', 5),
#  ('hakaishin', 5),
#  ('vscode', 5),
#  ('janeu', 5),
#  ('pérez', 5),
#  ('in2018', 5),
#  ('mern', 5),
#  ('intercast', 5),
#  ('prilims', 5),
#  ('xef4', 5),
#  ('sarso', 5),
#  ('cabba', 5),
#  ('phinks', 5),
#  ('tmisat', 5),
#  ('ngannou', 5),
#  ('pmegp', 5),
#  ('1lac', 5),
#  ('iubh', 5),
#  ('belmod', 5),
#  ('esdeath', 5),
#  ('calexit', 5),
#  ('sjmsom', 5),
#  ('918kiss', 5),
#  ('kotoamatsukami', 5),
#  ('perú', 5),
#  ('cos3x', 5),
#  ('calltend', 5),
#  ('yygs', 5),
#  ('kilgrave', 5),
#  ('gravational', 5),
#  ('potterverse', 5),
#  ('obergefell', 5),
#  ('nanodegrees', 5),
#  ('cortés', 5),
#  ('jn0', 5),
#  ('mirakee', 5),
#  ('iitgn', 5),
#  ('tutorialspoint', 5),
#  ('gerassimou', 5),
#  ('becl2', 5),
#  ('h1b1', 5),
#  ('deoghar', 5),
#  ('premam', 5),
#  ('gstr1', 5),
#  ('box8', 5),
#  ('200ah', 5),
#  ('neetpg', 5),
#  ('asansol', 5),
#  ('québécois', 5),
#  ('gate2018', 5),
#  ('danaerys', 5),
#  ('viserion', 5),
#  ('arunabh', 5),
#  ('c6h10', 5),
#  ('8values', 5),
#  ('bcl3', 5),
#  ('iipr', 5),
#  ('7600k', 5),
#  ('meosis', 5),
#  ('gaumutra', 5),
#  ('blackis', 5),
#  ('tedro', 5),
#  ('pgee', 5),
#  ('brexiting', 5),
#  ('plassey', 5),
#  ('hsd17b13', 5),
#  ('kreatryx', 5),
#  ('geostorm', 5),
#  ('splatoon', 5),
#  ('2lakh', 5),
#  ('aiimsonians', 5),
#  ('multibaggers', 5),
#  ('plexcoin', 5),
#  ('btcxindia', 5),
#  ('langague', 5),
#  ('teespring', 5),
#  ('whattsapp', 5),
#  ('thappar', 5),
#  ('ahch', 5),
#  ('wjy', 5),
#  ('gsuite', 5),
#  ('mavni', 5),
#  ('stateboard', 5),
#  ('nessler', 5),
#  ('perón', 5),
#  ('cat2017', 5),
#  ('sockistan', 5),
#  ('jaats', 5),
#  ('2k15', 5),
#  ('betterhelp', 5),
#  ('gtpl', 5),
#  ('mahcet', 5),
#  ('pétain', 5),
#  ('iphonex', 5),
#  ('cos6x', 5),
#  ('arctg', 5),
#  ('awadesh', 5),
#  ('prageru', 5),
#  ('filmora', 5),
#  ('khazari', 5),
#  ('ï', 4),
#  ('asifas', 4),
#  ('ndeb', 4),
#  ('kỳ', 4),
#  ('dsim', 4),
#  ('deplation', 4),
#  ('smvdu', 4),
#  ('chlef', 4),
#  ('dragnea', 4),
#  ('aissce', 4),
#  ('10rs', 4),
#  ('stcg', 4),
#  ('khalistanis', 4)]

# %% [markdown]
# What's still missing ?
# > * Unknown words
# > * Acronyms
# > * Spelling mistakes

# %% [markdown]
# ### We can correct manually most frequent mispells
# For example, here are some mistakes and their frequency
#
#     qoura : 85 times
#     mastrubation : 38 times
#     demonitisation : 30 times
#     …

# %%
mispell = {'colour': 'color', 'centre': 'center', 'favourite': 'favorite', 'travelling': 'traveling',
           'counselling': 'counseling', 'theatre': 'theater', 'cancelled': 'canceled', 'labour': 'labor',
           'organisation': 'organization', 'wwii': 'world war 2', 'citicise': 'criticize', 'youtu': 'youtube ',
           'qoura': 'quora', 'quorans': 'quora users', 'quoran': 'quora user', 'sallary': 'salary', 'whta': 'what',
           'narcisist': 'narcissist', 'howdo': 'how do', 'whatare': 'what are', 'howcan': 'how can', 'howmuch': 'how much',
           'howmany': 'how many', 'whydo': 'why do', 'doi': 'do i', 'thebest': 'the best', 'howdoes': 'how does',
           'mastrubation': 'masturbation', 'mastrubate': 'masturbate', "mastrubating": 'masturbating',
           'pennis': 'penis', 'etherium': 'ethereum', 'narcissit': 'narcissist', 'bigdata': 'big data',
           '2k15': '2015', '2k16': '2016', '2k17': '2017', '2k18': '2018', 'qouta': 'quota', 'exboyfriend': 'ex boyfriend',
           'airhostess': 'air hostess', "whst": 'what', 'watsapp': 'whatsapp', 'demonitisation': 'demonetization',
           'demonitization': 'demonetization', 'demonetisation': 'demonetization', 'pokémon': 'pokemon',
           'nanodegree': 'nano degree', 'brexit': 'british exit', 'cryptocurrencies': 'crypto currencies',
           'coinbase': 'coin base', 'oneplus': 'one plus', 'redmi': 'red mi', 'GDPR': 'general data protection regulation',
           'DCEU': 'dc extended universe', 'litecoin': 'lite coin', 'unacademy': 'non academy', 'altcoin': 'bitcoin alternative',
           'altcoins': 'bitcoin alternative', 'sjw': 'social justice warriors', 'sjws': 'social justice warriors',
           'fiancé': 'fiance', 'microservices': 'micro services', 'bitconnect': 'bit connect', 'codeforces': 'code forces',
           'wannacry': 'wanna cry', 'onedrive': 'one drive', 'airpods': 'air pods', 'twinflame': 'twin flame',
           'undergraduation': 'under graduation', 'cos2x': 'cos 2 x', 'yourquote': 'your quote', 'xiomi': 'xiaomi',
           'undertale': 'under tale', 'genderfluid': 'gender fluid', 'são': 'sao', 'chapterwise': 'chapter wise',
           'deepmind': 'deep mind', '': '', 'arrowverse': 'arrow verse', 'overbrace': ' ', 'tensorflow': 'tensor flow',
           'hackerrank': 'hacker rank', 'microservice': 'micro service', 'reactjs': 'react js', 'hackerearth': 'hacker earth',
           'fiancée': 'fiance', 'blockchains': 'block chains', 'beyoncé': 'beyonce', 'neuralink': 'neura link',
           'openai': 'open ai', 'zoomcar': 'zoom car', 'hyperconjugation': 'hyper conjugation', 'autoencoder': 'auto encoder',
           'webassembly': 'web assembly', 'quoras': 'quora', 'digilocker': 'digi locker', 'oversmart': 'over smart',
           'cryptocoins': 'crypto coins', 'crytocurrencies': 'cryto currencies', 'cyrptocurrency': 'cyrpto currency',
           'café': 'cafe', 'whatapp': 'whatsapp', 'gaslighter': 'gas lighter', 'darkweb': 'dark web', 'webnovel': 'web novel'}

# %%
def correct_spelling(x, mapping):
    for word in mapping.keys():
        x = x.replace(word, mapping[word])
    return x

# %%
df['treated_question'] = df['treated_question'].progress_apply(lambda x: correct_spelling(x, mispell))
# Out:
# 100%|██████████| 1362492/1362492 [00:24<00:00, 56168.74it/s]

# %%
vocab = build_vocab(df['treated_question'])
print("Glove : ")
oov_glove = check_coverage(vocab, emb_glove)
# Out:
# Glove :
# Found embeddings for 69.237% of vocab
# Found embeddings for  99.602% of all text

# %%
print(len(oov_glove))
oov_glove
# Out:
# 61472
# [('uceed', 126),
#  ('bhakts', 118),
#  ('upwork', 117),
#  ('machedo', 112),
#  ('gdpr', 110),
#  ('adityanath', 108),
#  ('bnbr', 105),
#  ('boruto', 105),
#  ('alshamsi', 100),
#  ('dceu', 94),
#  ('iiest', 91),
#  ('warriorss', 89),
#  ('zerodha', 85),
#  ('lnmiit', 73),
#  ('kavalireddi', 71),
#  ('doklam', 70),
#  ('muoet', 68),
#  ('nicmar', 66),
#  ('vajiram', 62),
#  ('srmjee', 61),
#  ('adhaar', 60),
#  ('zebpay', 58),
#  ('elitmus', 58),
#  ('jiren', 56),
#  ('awdhesh', 55),
#  ('ryzen', 51),
#  ('koinex', 50),
#  ('baahubali', 48),
#  ('mhcet', 47),
#  ('byju', 47),
#  ('binance', 46),
#  ('srmjeee', 44),
#  ('beerus', 43),
#  ('ftre', 42),
#  ('skripal', 42),
#  ('sgsits', 42),
#  ('mhtcet', 40),
#  ('hotstar', 40),
#  ('gurugram', 40),
#  ('bipc', 39),
#  ('lbsnaa', 38),
#  ('bmsce', 38),
#  ('jiofi', 38),
#  ('sarahah', 36),
#  ('ravula', 36),
#  ('swachh', 36),
#  ('obor', 35),
#  ('usict', 34),
#  ('patreon', 34),
#  ('clickbait', 34),
#  ('zenfone', 33),
#  ('iisers', 33),
#  ('bittrex', 32),
#  ('chromecast', 32),
#  ('pessat', 31),
#  ('jungkook', 30),
#  ('xxxtentacion', 30),
#  ('dream11', 30),
#  ('kalpit', 29),
#  ('mmmut', 29),
#  ('aktu', 29),
#  ('trumpcare', 28),
#  ('rlwl', 27),
#  ('aiats', 27),
#  ('hbtu', 26),
#  ('zamasu', 26),
#  ('irodov', 25),
#  ('despacito', 25),
#  ('simpliv', 25),
#  ('nlus', 25),
#  ('vssut', 25),
#  ('electroneum', 24),
#  ('fz25', 24),
#  ('lnct', 24),
#  ('kubernetes', 24),
#  ('iiitd', 23),
#  ('eflu', 23),
#  ('igdtuw', 23),
#  ('kovind', 23),
#  ('iiith', 23),
#  ('wrongdo', 23),
#  ('internshala', 23),
#  ('makaut', 22),
#  ('zhihu', 22),
#  ('padmavat', 22),
#  ('ravindrababu', 22),
#  ('incels', 22),
#  ('ncerts', 22),
#  ('josé', 22),
#  ('padmaavat', 22),
#  ('veerwal', 21),
#  ('remainers', 21),
#  ('byjus', 21),
#  ('schizoids', 21),
#  ('extc', 21),
#  ('vitee', 21),
#  ('jcpoa', 21),
#  ('tissnet', 21),
#  ('apist', 21),
#  ('ifos', 20),
#  ('theranos', 20),
#  ('pizzagate', 20),
#  ('ipmat', 20),
#  ('odoo', 20),
#  ('pmay', 20),
#  ('covfefe', 19),
#  ('strzok', 19),
#  ('kaneki', 19),
#  ('dhinchak', 19),
#  ('clichés', 19),
#  ('awdesh', 19),
#  ('steemit', 19),
#  ('wikitribune', 19),
#  ('fullform', 19),
#  ('bitfinex', 18),
#  ('iihm', 18),
#  ('déja', 18),
#  ('drumpf', 18),
#  ('d3300', 18),
#  ('ailet', 18),
#  ('sscbs', 18),
#  ('atatürk', 17),
#  ('hsee', 17),
#  ('kgmu', 17),
#  ('mbappe', 17),
#  ('lhmc', 17),
#  ('करन', 17),
#  ('1300d', 17),
#  ('kattankulathur', 17),
#  ('instacart', 17),
#  ('bmsit', 17),
#  ('jupyter', 17),
#  ('qidian', 17),
#  ('क', 17),
#  ('erdoğan', 17),
#  ('aieea', 16),
#  ('ह', 16),
#  ('neura', 16),
#  ('class11', 16),
#  ('940mx', 16),
#  ('usaco', 16),
#  ('mobikwik', 16),
#  ('whyis', 16),
#  ('warmbier', 16),
#  ('upeseat', 16),
#  ('rgipt', 16),
#  ('pgdbf', 16),
#  ('taehyung', 16),
#  ('nitians', 16),
#  ('msqe', 16),
#  ('doordash', 16),
#  ('nsejs', 16),
#  ('pesu', 16),
#  ('ahok', 16),
#  ('homepod', 16),
#  ('kainerugaba', 16),
#  ('fitjee', 15),
#  ('flipcart', 15),
#  ('minance', 15),
#  ('vitmee', 15),
#  ('160r', 15),
#  ('igst', 15),
#  ('hashflare', 15),
#  ('toppr', 15),
#  ('feku', 15),
#  ('ipucet', 15),
#  ('ω', 15),
#  ('killmonger', 15),
#  ('mh370', 15),
#  ('leetcode', 15),
#  ('françois', 15),
#  ('schrödinger', 15),
#  ('sayat', 15),
#  ('montréal', 15),
#  ('wumao', 14),
#  ('jiophone', 14),
#  ('unocoin', 14),
#  ('dogecoin', 14),
#  ('segwit2x', 14),
#  ('nluo', 14),
#  ('alphago', 14),
#  ('tamilans', 14),
#  ('freecodecamp', 14),
#  ('kefla', 14),
#  ('gstin', 14),
#  ('dsce', 14),
#  ('ipill', 14),
#  ('ugee', 14),
#  ('mh17', 14),
#  ('jecrc', 14),
#  ('exiters', 14),
#  ('plancess', 14),
#  ('cliché', 14),
#  ('nielit', 14),
#  ('daesh', 14),
#  ('d7200', 14),
#  ('onecoin', 14),
#  ('ubereats', 14),
#  ('musigma', 13),
#  ('angular2', 13),
#  ('phonepe', 13),
#  ('niftem', 13),
#  ('practo', 13),
#  ('opham', 13),
#  ('poloniex', 13),
#  ('iict', 13),
#  ('7700k', 13),
#  ('ballb', 13),
#  ('sppu', 13),
#  ('thé', 13),
#  ('digitalocean', 13),
#  ('aimcat', 13),
#  ('deplorables', 13),
#  ('covalency', 13),
#  ('waymo', 13),
#  ('imucet', 13),
#  ('lrdi', 13),
#  ('uppcs', 12),
#  ('kasganj', 12),
#  ('techmahindra', 12),
#  ('rené', 12),
#  ('gödel', 12),
#  ('trumpism', 12),
#  ('eu4', 12),
#  ('dilr', 12),
#  ('sanghis', 12),
#  ('δ', 12),
#  ('etoos', 12),
#  ('mpstme', 12),
#  ('1050ti', 12),
#  ('nearbuy', 12),
#  ('sklearn', 12),
#  ('iert', 12),
#  ('exiteers', 12),
#  ('bumrah', 12),
#  ('incel', 12),
#  ('rwby', 12),
#  ('tqwl', 12),
#  ('kilimall', 12),
#  ('hypsm', 12),
#  ('émile', 11),
#  ('rnsit', 11),
#  ('vesit', 11),
#  ('freebitco', 11),
#  ('rbei', 11),
#  ('erc20', 11),
#  ('class9', 11),
#  ('gdax', 11),
#  ('lenskart', 11),
#  ('d5300', 11),
#  ('pgdie', 11),
#  ('7200u', 11),
#  ('oliveboard', 11),
#  ('trezor', 11),
#  ('padmé', 11),
#  ('arkit', 11),
#  ('otsutsuki', 11),
#  ('fayol', 11),
#  ('rcoem', 11),
#  ('graphql', 11),
#  ('antminer', 11),
#  ('prmo', 11),
#  ('bartetzko', 11),
#  ('cooh', 11),
#  ('shippūden', 11),
#  ('simsree', 11),
#  ('andré', 10),
#  ('datacamp', 10),
#  ('rnns', 10),
#  ('petuhov', 10),
#  ('madeeasy', 10),
#  ('cptsd', 10),
#  ('filecoin', 10),
#  ('igrua', 10),
#  ('thicc', 10),
#  ('alphazero', 10),
#  ('bstat', 10),
#  ('kgmc', 10),
#  ('etherum', 10),
#  ('λ', 10),
#  ('gujratis', 10),
#  ('gurmehar', 10),
#  ('bolsonaro', 10),
#  ('gaslighted', 10),
#  ('cph4', 10),
#  ('carplay', 10),
#  ('strowman', 10),
#  ('φ', 10),
#  ('testbook', 10),
#  ('cas9', 10),
#  ('pytorch', 10),
#  ('hololens', 10),
#  ('tambrahms', 10),
#  ('oswaal', 10),
#  ('xender', 10),
#  ('rakshaks', 10),
#  ('cringiest', 10),
#  ('ciaz', 10),
#  ('fnaf', 10),
#  ('iqoption', 10),
#  ('sense8', 10),
#  ('bschools', 10),
#  ('cryto', 10),
#  ('qyburn', 10),
#  ('ge14', 10),
#  ('siacoin', 10),
#  ('5lpa', 10),
#  ('krennic', 10),
#  ('ns200', 10),
#  ('niccolò', 10),
#  ('d3400', 9),
#  ('k2cr2o7', 9),
#  ('doky', 9),
#  ('nitian', 9),
#  ('urbanclap', 9),
#  ('lpunest', 9),
#  ('gonzález', 9),
#  ('delloite', 9),
#  ('pmkvy', 9),
#  ('digibank', 9),
#  ('vistara', 9),
#  ('cotx', 9),
#  ('serbo', 9),
#  ('aimcats', 9),
#  ('azdome', 9),
#  ('neet2017', 9),
#  ('σ', 9),
#  ('wilp', 9),
#  ('got7', 9),
#  ('tspsc', 9),
#  ('empowr', 9),
#  ('scoopwhoop', 9),
#  ('bvcoe', 9),
#  ('debotosh', 9),
#  ('ditiss', 9),
#  ('tezos', 9),
#  ('midoriya', 9),
#  ('rejuvalex', 9),
#  ('ciwg', 9),
#  ('juit', 9),
#  ('frdi', 9),
#  ('a2as', 9),
#  ('gtbit', 9),
#  ('haptik', 9),
#  ('γ', 9),
#  ('bftech', 9),
#  ('nofap', 9),
#  ('1080ti', 9),
#  ('win10', 9),
#  ('aayog', 9),
#  ('fadnavis', 9),
#  ('alovera', 9),
#  ('gitlab', 9),
#  ('iiitdm', 9),
#  ('jnuee', 9),
#  ('jeemains', 9),
#  ('delhite', 9),
#  ('मर', 9),
#  ('touchbar', 9),
#  ('brontë', 9),
#  ('crytocurrency', 9),
#  ('suryanamaskar', 9),
#  ('vuejs', 9),
#  ('québec', 9),
#  ('baslp', 9),
#  ('indominus', 9),
#  ('bajjika', 9),
#  ('raúl', 8),
#  ('uncollapse', 8),
#  ('avenatti', 8),
#  ('sricity', 8),
#  ('rajyasabha', 8),
#  ('wishfie', 8),
#  ('clichéd', 8),
#  ('novichok', 8),
#  ('thighing', 8),
#  ('cocubes', 8),
#  ('iitkgp', 8),
#  ('8700k', 8),
#  ('hyperthymesia', 8),
#  ('dapps', 8),
#  ('naïve', 8),
#  ('islamaphobic', 8),
#  ('jeemain', 8),
#  ('tallentex', 8),
#  ('snapchats', 8),
#  ('antshares', 8),
#  ('lstms', 8),
#  ('sallery', 8),
#  ('coching', 8),
#  ('mangalyaan', 8),
#  ('sapiosexual', 8),
#  ('quorians', 8),
#  ('biromantic', 8),
#  ('philando', 8),
#  ('bowdo', 8),
#  ('kygo', 8),
#  ('nmamit', 8),
#  ('mysuru', 8),
#  ('antardasha', 8),
#  ('misérables', 8),
#  ('jozwik', 8),
#  ('skripals', 8),
#  ('scripbox', 8),
#  ('2theta', 8),
#  ('fmge', 8),
#  ('sokovia', 8),
#  ('école', 8),
#  ('class12', 8),
#  ('vidyalankar', 8),
#  ('b1b2', 8),
#  ('fullstack', 8),
#  ('word2vec', 8),
#  ('stardew', 8),
#  ('umtiti', 8),
#  ('cosecx', 8),
#  ('cucet', 8),
#  ('digibyte', 8),
#  ('playerunknown', 8),
#  ('uttarpradesh', 8),
#  ('note4', 8),
#  ('insofe', 8),
#  ('worldquant', 8),
#  ('buildbox', 7),
#  ('pivx', 7),
#  ('preboards', 7),
#  ('elementor', 7),
#  ('cyrpto', 7),
#  ('terroristan', 7),
#  ('mangalapuram', 7),
#  ('nagerkovil', 7),
#  ('rgnul', 7),
#  ('blackpink', 7),
#  ('happeno', 7),
#  ('esp8266', 7),
#  ('yiannopolous', 7),
#  ('nitroaniline', 7),
#  ('jiménez', 7),
#  ('mvsr', 7),
#  ('techm', 7),
#  ('döner', 7),
#  ('hashgraph', 7),
#  ('deliveroo', 7),
#  ('rastra', 7),
#  ('syeds', 7),
#  ('1000rs', 7),
#  ('bathla', 7),
#  ('mevani', 7),
#  ('g4560', 7),
#  ('whatsaap', 7),
#  ('sairat', 7),
#  ('omscs', 7),
#  ('rmlnlu', 7),
#  ('blinkist', 7),
#  ('zürich', 7),
#  ('ı', 7),
#  ('pubdet', 7),
#  ('tenseigan', 7),
#  ('whivh', 7),
#  ('vantablack', 7),
#  ('gfrg', 7),
#  ('payumoney', 7),
#  ('myetherwallet', 7),
#  ('momoshiki', 7),
#  ('bimaru', 7),
#  ('centillion', 7),
#  ('fuckboys', 7),
#  ('991ms', 7),
#  ('dubsmash', 7),
#  ('nitc', 7),
#  ('psit', 7),
#  ('cryptocoin', 7),
#  ('manspreading', 7),
#  ('mewani', 7),
#  ('kejariwal', 7),
#  ('foodpanda', 7),
#  ('ghazwa', 7),
#  ('düsseldorf', 7),
#  ('cleartax', 7),
#  ('theeta', 7),
#  ('1crore', 7),
#  ('devasena', 7),
#  ('bluemix', 7),
#  ('gbwhatsapp', 7),
#  ('locopilot', 7),
#  ('trumpsters', 7),
#  ('mersal', 7),
#  ('izuku', 7),
#  ('y53', 7),
#  ('nidahas', 7),
#  ('puneri', 7),
#  ('garud', 7),
#  ('kekistan', 7),
#  ('uipath', 7),
#  ('tapzo', 7),
#  ('freshworks', 7),
#  ('ψ', 7),
#  ('dsatm', 7),
#  ('rautela', 7),
#  ('iitram', 7),
#  ('पर', 7),
#  ('म', 7),
#  ('thadomal', 7),
#  ('aghoris', 7),
#  ('jgls', 7),
#  ('gazwa', 7),
#  ('parmanu', 7),
#  ('isbf', 7),
#  ('nuals', 7),
#  ('bhallaladeva', 7),
#  ('polyhouse', 7),
#  ('madheshis', 7),
#  ('xvg', 7),
#  ('intenship', 7),
#  ('zcash', 7),
#  ('qtum', 7),
#  ('demonatisation', 7),
#  ('juicero', 7),
#  ('juárez', 7),
#  ('satoshis', 7),
#  ('landran', 7),
#  ('upvoters', 7),
#  ('costheta', 7),
#  ('testdaf', 7),
#  ('randyll', 7),
#  ('igtv', 7),
#  ('sharudenko', 7),
#  ('ekyc', 7),
#  ('pgdhrm', 7),
#  ('xcent', 7),
#  ('ichange', 7),
#  ('westbengal', 7),
#  ('bregoli', 7),
#  ('nanoray', 7),
#  ('žižek', 7),
#  ('卐', 6),
#  ('lahren', 6),
#  ('ambarella', 6),
#  ('elxsi', 6),
#  ('venturimeter', 6),
#  ('sinb', 6),
#  ('bhumihar', 6),
#  ('baiyue', 6),
#  ('narcicist', 6),
#  ('commonapp', 6),
#  ('avpd', 6),
#  ('tenkasi', 6),
#  ('mukt', 6),
#  ('kgec', 6),
#  ('alshami', 6),
#  ('oberlo', 6),
#  ('brachistochrone', 6),
#  ('göring', 6),
#  ('991es', 6),
#  ('hindians', 6),
#  ('evion', 6),
#  ('malmö', 6),
#  ('workex', 6),
#  ('tuee', 6),
#  ('kersee', 6),
#  ('mechnovate', 6),
#  ('dcrust', 6),
#  ('hapnes', 6),
#  ('ssjb', 6),
#  ('iitjam', 6),
#  ('powerbanks', 6),
#  ('relu', 6),
#  ('offerup', 6),
#  ('paramhansha', 6),
#  ('xenoverse', 6),
#  ('iiitb', 6),
#  ('μ', 6),
#  ('ossoff', 6),
#  ('korotkevich', 6),
#  ('xgboost', 6),
#  ('staybay', 6),
#  ('lbsim', 6),
#  ('dmart', 6),
#  ('segwit', 6),
#  ('gateforum', 6),
#  ('sgtb', 6),
#  ('aimim', 6),
#  ('2lakhs', 6),
#  ('divyansh', 6),
#  ('kahoot', 6),
#  ('eastwatch', 6),
#  ('dentacoin', 6),
#  ('maría', 6),
#  ('iphone7', 6),
#  ('1mole', 6),
#  ('golgappa', 6),
#  ('blockstack', 6),
#  ('shifuji', 6),
#  ('antibrahmin', 6),
#  ('ōtsutsuki', 6),
#  ('nestaway', 6),
#  ('allincall', 6),
#  ('diprotic', 6),
#  ('h3po3', 6),
#  ('cryptocurreny', 6),
#  ('dichlorine', 6),
#  ('whyare', 6),
#  ('trignometric', 6),
#  ('mastuburation', 6),
#  ('freecharge', 6),
#  ('bakliwal', 6),
#  ('tfws', 6),
#  ('namikaze', 6),
#  ('remoaners', 6),
#  ('geometrifying', 6),
#  ('qué', 6),
#  ('geeksforgeeks', 6),
#  ('openload', 6),
#  ('cuphead', 6),
#  ('rojava', 6),
#  ('muchhal', 6),
#  ('markiplier', 6),
#  ('edureka', 6),
#  ('fe3', 6),
#  ('6300hq', 6),
#  ('oumuamua', 6),
#  ('jio4gvoice', 6),
#  ('snapay', 6),
#  ('dimash', 6),
#  ('r558uq', 6),
#  ('xef6', 6),
#  ('vidmate', 6),
#  ('wakad', 6),
#  ('4xy', 6),
#  ('trumpists', 6),
#  ('mélenchon', 6),
#  ('kissanime', 6),
#  ('fifa17', 6),
#  ('eindiawholesale', 6),
#  ('s7e7', 6),
#  ('kingroot', 6),
#  ('dujat', 6),
#  ('fasttext', 6),
#  ('amwf', 6),
#  ('laliga', 6),
#  ('iittm', 6),
#  ('hardhome', 6),
#  ('na2s2o3', 6),
#  ('tracxn', 6),
#  ('nitw', 6),
#  ('qspiders', 6),
#  ('niacl', 6),
#  ('caulifla', 6),
#  ('mvit', 6),
#  ('renée', 6),
#  ('toneri', 6),
#  ('etherparty', 6),
#  ('animoji', 6),
#  ('führer', 6),
#  ('spipa', 6),
#  ('resofast', 6),
#  ('xapo', 6),
#  ('nodemcu', 6),
#  ('लगन', 6),
#  ('bytecoin', 6),
#  ('phycopath', 6),
#  ('pyqt5', 6),
#  ('cryptocurency', 6),
#  ('garrix', 6),
#  ('vaporwave', 6),
#  ('electrovalent', 6),
#  ('edwisor', 6),
#  ('mstat', 6),
#  ('howdid', 6),
#  ('ios11', 6),
#  ('trumpian', 6),
#  ('pibm', 6),
#  ('possesiveness', 6),
#  ('chhillar', 6),
#  ('lmrc', 6),
#  ('tigor', 6),
#  ('sevmeyene', 6),
#  ('mpharm', 6),
#  ('aiactr', 6),
#  ('jgec', 6),
#  ('aksener', 6),
#  ('université', 6),
#  ('cac2', 5),
#  ('enchroma', 5),
#  ('résumé', 5),
#  ('namakharam', 5),
#  ('mitsom', 5),
#  ('tsicet', 5),
#  ('kattappa', 5),
#  ('lópez', 5),
#  ('pgpem', 5),
#  ('ffcs', 5),
#  ('rc200', 5),
#  ('protonmail', 5),
#  ('speedforce', 5),
#  ('dictorship', 5),
#  ('t6i', 5),
#  ('ukvi', 5),
#  ('rohinga', 5),
#  ('tanb', 5),
#  ('å', 5),
#  ('sickular', 5),
#  ('ppdt', 5),
#  ('hyps', 5),
#  ('methanoic', 5),
#  ('sin3x', 5),
#  ('कय', 5),
#  ('kolkey', 5),
#  ('howis', 5),
#  ('gearbest', 5),
#  ('kivy', 5),
#  ('r15s', 5),
#  ('stayuncle', 5),
#  ('piwat', 5),
#  ('doscos', 5),
#  ('woxsen', 5),
#  ('bitmoji', 5),
#  ('iofs', 5),
#  ('prepation', 5),
#  ('bijwasan', 5),
#  ('pahul', 5),
#  ('ayog', 5),
#  ('icetratt', 5),
#  ('joão', 5),
#  ('u0001f914', 5),
#  ('vaxxers', 5),
#  ('demonitised', 5),
#  ('redme', 5),
#  ('humanties', 5),
#  ('odissa', 5),
#  ('h3po2', 5),
#  ('neduvasal', 5),
#  ('ramanujam', 5),
#  ('studienkolleg', 5),
#  ('shingrix', 5),
#  ('côte', 5),
#  ('nliu', 5),
#  ('altacoin', 5),
#  ('limeroad', 5),
#  ('icitss', 5),
#  ('pillani', 5),
#  ('iphone6', 5),
#  ('ⁿ', 5),
#  ('5cr', 5),
#  ('accolite', 5),
#  ('bakths', 5),
#  ('udan', 5),
#  ('spaghettification', 5),
#  ('katappa', 5),
#  ('songkhla', 5),
#  ('brasília', 5),
#  ('msruas', 5),
#  ('overcaring', 5),
#  ('garoppolo', 5),
#  ('wbpsc', 5),
#  ('thyronorm', 5),
#  ('openshift', 5),
#  ('bnys', 5),
#  ('mgtows', 5),
#  ('duplet', 5),
#  ('disapparate', 5),
#  ('varrier', 5),
#  ('anlamaz', 5),
#  ('त', 5),
#  ('resumé', 5),
#  ('superscore', 5),
#  ('6200u', 5),
#  ('econimics', 5),
#  ('mitid', 5),
#  ('katalon', 5),
#  ('liangelo', 5),
#  ('özil', 5),
#  ('tamoghna', 5),
#  ('asgardia', 5),
#  ('databricks', 5),
#  ('français', 5),
#  ('आन', 5),
#  ('3sin', 5),
#  ('quroa', 5),
#  ('weatern', 5),
#  ('addhar', 5),
#  ('curaçao', 5),
#  ('statergy', 5),
#  ('seq2seq', 5),
#  ('wbchse', 5),
#  ('c2h2', 5),
#  ('subnautica', 5),
#  ('एक', 5),
#  ('ramrahim', 5),
#  ('balayam', 5),
#  ('nseb', 5),
#  ('codevita', 5),
#  ('yondu', 5),
#  ('whtsapp', 5),
#  ('ellaria', 5),
#  ('pshycology', 5),
#  ('ntorq', 5),
#  ('7300hq', 5),
#  ('etmoney', 5),
#  ('miui9', 5),
#  ('bodnick', 5),
#  ('matram', 5),
#  ('mahadasa', 5),
#  ('b777', 5),
#  ('tanjavur', 5),
#  ('jiocoin', 5),
#  ('narcassist', 5),
#  ('hnlu', 5),
#  ('decofest', 5),
#  ('feminazism', 5),
#  ('gangrapes', 5),
#  ('chaiwala', 5),
#  ('mnlu', 5),
#  ('état', 5),
#  ('pixelbook', 5),
#  ('mutarotation', 5),
#  ('heilongjiang', 5),
#  ('interviewbit', 5),
#  ('mahishmati', 5),
#  ('méxico', 5),
#  ('cryptoassets', 5),
#  ('bíró', 5),
#  ('lászló', 5),
#  ('hakaishin', 5),
#  ('vscode', 5),
#  ('janeu', 5),
#  ('pérez', 5),
#  ('in2018', 5),
#  ('mern', 5),
#  ('intercast', 5),
#  ('prilims', 5),
#  ('xef4', 5),
#  ('sarso', 5),
#  ('cabba', 5),
#  ('phinks', 5),
#  ('tmisat', 5),
#  ('ngannou', 5),
#  ('pmegp', 5),
#  ('1lac', 5),
#  ('iubh', 5),
#  ('plus5', 5),
#  ('belmod', 5),
#  ('esdeath', 5),
#  ('calexit', 5),
#  ('sjmsom', 5),
#  ('918kiss', 5),
#  ('kotoamatsukami', 5),
#  ('perú', 5),
#  ('cos3x', 5),
#  ('calltend', 5),
#  ('yygs', 5),
#  ('kilgrave', 5),
#  ('gravational', 5),
#  ('potterverse', 5),
#  ('obergefell', 5),
#  ('cortés', 5),
#  ('jn0', 5),
#  ('mirakee', 5),
#  ('iitgn', 5),
#  ('tutorialspoint', 5),
#  ('gerassimou', 5),
#  ('becl2', 5),
#  ('h1b1', 5),
#  ('deoghar', 5),
#  ('premam', 5),
#  ('gstr1', 5),
#  ('box8', 5),
#  ('200ah', 5),
#  ('neetpg', 5),
#  ('asansol', 5),
#  ('québécois', 5),
#  ('gate2018', 5),
#  ('danaerys', 5),
#  ('viserion', 5),
#  ('arunabh', 5),
#  ('c6h10', 5),
#  ('8values', 5),
#  ('bcl3', 5),
#  ('iipr', 5),
#  ('7600k', 5),
#  ('meosis', 5),
#  ('gaumutra', 5),
#  ('blackis', 5),
#  ('tedro', 5),
#  ('pgee', 5),
#  ('plassey', 5),
#  ('hsd17b13', 5),
#  ('kreatryx', 5),
#  ('geostorm', 5),
#  ('splatoon', 5),
#  ('2lakh', 5),
#  ('aiimsonians', 5),
#  ('multibaggers', 5),
#  ('plexcoin', 5),
#  ('btcxindia', 5),
#  ('langague', 5),
#  ('teespring', 5),
#  ('whattsapp', 5),
#  ('thappar', 5),
#  ('ahch', 5),
#  ('wjy', 5),
#  ('gsuite', 5),
#  ('mavni', 5),
#  ('stateboard', 5),
#  ('nessler', 5),
#  ('perón', 5),
#  ('cat2017', 5),
#  ('sockistan', 5),
#  ('jaats', 5),
#  ('betterhelp', 5),
#  ('gtpl', 5),
#  ('mahcet', 5),
#  ('pétain', 5),
#  ('iphonex', 5),
#  ('cos6x', 5),
#  ('arctg', 5),
#  ('awadesh', 5),
#  ('prageru', 5),
#  ('filmora', 5),
#  ('khazari', 5),
#  ('ï', 4),
#  ('asifas', 4),
#  ('ndeb', 4),
#  ('kỳ', 4),
#  ('dsim', 4),
#  ('deplation', 4),
#  ('smvdu', 4),
#  ('chlef', 4),
#  ('dragnea', 4),
#  ('aissce', 4),
#  ('10rs', 4),
#  ('stcg', 4),
#  ('khalistanis', 4),
#  ('narcissts', 4),
#  ('talabat', 4),
#  ('ankeeta', 4),
#  ('liberland', 4),
#  ('printful', 4),
#  ('cliven', 4),
#  ('sjbit', 4),
#  ('bhubhaneshwar', 4),
#  ('savitribai', 4),
#  ('7lpa', 4),
#  ('ambiverts', 4),
#  ('propan', 4),
#  ('filpkart', 4),
#  ('contentmart', 4),
#  ('naharis', 4),
#  ('léon', 4),
#  ('gftis', 4),
#  ('interledger', 4),
#  ('pulisic', 4),
#  ('khloé', 4),
#  ('khajida', 4),
#  ('و', 4),
#  ('ch3ch', 4),
#  ('tewani', 4),
#  ('medicaps', 4),
#  ('mohammedia', 4),
#  ('ioaa', 4),
#  ('tybcom', 4),
#  ('retainership', 4),
#  ('cyient', 4),
#  ('cishet', 4),
#  ('sohag', 4),
#  ('russiagate', 4),
#  ('coinspot', 4),
#  ('enggineering', 4),
#  ('narccisist', 4),
#  ('upcpat', 4),
#  ('españa', 4),
#  ('bvbcet', 4),
#  ('parshurama', 4),
#  ('quorian', 4),
#  ('ixalan', 4),
#  ('diffentiate', 4),
#  ('lanthanoids', 4),
#  ('pgdav', 4),
#  ('pgdac', 4),
#  ('acsir', 4),
#  ('microneedling', 4),
#  ('mobdro', 4),
#  ('qled', 4),
#  ('selfstudy', 4),
#  ('kurud', 4),
#  ('tilki', 4),
#  ('mānuka', 4),
#  ('13rw', 4),
#  ('cr2o7', 4),
#  ('veltech', 4),
#  ('tejasvita', 4),
#  ('meliodas', 4),
#  ('similarweb', 4),
#  ('jspider', 4),
#  ('ulaanbaatar', 4),
#  ('uraraka', 4),
#  ('wittyfeed', 4),
#  ('bramhin', 4),
#  ('actinoids', 4),
#  ('omnet', 4),
#  ...]

# %%
# # 外部拼写纠错工具（平台没有，需要申请安装）
# import enchant

# mispell_mapping = {}
# d = enchant.Dict("en_US")
# min_count = 5

# for item in oov_glove:
#     w = item[0]
#     if item[1] >= min_count:
#         r = d.suggest(w)
#         if r:
#             mispell_mapping[w] = r[0]
#         else:
#             mispell_mapping[w] = ''

# print(mispell_mapping)

# %%
# df['treated_question'] = df['treated_question'].progress_apply(lambda x: correct_spelling(x, mispell_mapping))

# %%
# vocab = build_vocab(df['treated_question'])
# print("Glove : ")
# oov_glove = check_coverage(vocab, emb_glove)

# %%
def clean_numbers(x):
    x = re.sub('[0-9]{5,}', '#####', x)
    x = re.sub('[0-9]{4}', '####', x)
    x = re.sub('[0-9]{3}', '###', x)
    x = re.sub('[0-9]{2}', '##', x)
    return x

# %%
df['treated_question'] = df['treated_question'].progress_apply(lambda x: clean_numbers(x))
# Out:
# 100%|██████████| 1362492/1362492 [00:10<00:00, 124320.14it/s]

# %%
vocab = build_vocab(df['treated_question'])
print("Glove : ")
oov_glove = check_coverage(vocab, emb_glove)
# Out:
# Glove :
# Found embeddings for 68.648% of vocab
# Found embeddings for  99.512% of all text
